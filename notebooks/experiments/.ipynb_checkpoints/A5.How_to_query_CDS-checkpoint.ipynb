# %% [markdown]
# # How to query CDS to get data on the correct grid
#
#
# A trick from Mat Chantry

# %%
import cdsapi

# %%
savedir = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/NewEraFields/'
c = cdsapi.Client()
times = [f'{i:02d}:00:00' for i in range(24)]
c.retrieve("reanalysis-era5-complete",
           {  
               'type'    : 'an',
               'param'   : '235',
               'levtype' : 'sfc',
               'date'    : '2016-01-01/to/2016-01-01',
               'time'    :  times,
               'format'  : 'grib', # Default: grib
           }, 
           savedir+'output.grib')
# Out:
# 2022-06-07 14:43:18,478 INFO Welcome to the CDS
# 2022-06-07 14:43:18,481 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-complete
# 2022-06-07 14:43:18,539 INFO Request is queued
# 2022-06-07 14:55:38,995 INFO Request is completed
# 2022-06-07 14:55:38,999 INFO Downloading https://download-0015-clone.copernicus-climate.eu/cache-compute-0015/cache/data3/adaptor.mars.external-1654610073.4989564-27464-14-7ce15be3-bbe3-4d4c-bd44-13c09d3ff53c.grib to /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/NewEraFields/output.grib (3.1M)
# 2022-06-07 14:55:41,314 INFO Download rate 1.3M/s
# Result(content_length=3256920,content_type=application/x-grib,location=https://download-0015-clone.copernicus-climate.eu/cache-compute-0015/cache/data3/adaptor.mars.external-1654610073.4989564-27464-14-7ce15be3-bbe3-4d4c-bd44-13c09d3ff53c.grib)

# %%
import xarray as xr

# %%
ds = xr.open_dataset(savedir+'output.grib',engine='cfgrib',backend_kwargs={'indexpath': ''})

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 3)>
# array(['2016-01-01T00:00:00.000000000', '2016-01-01T01:00:00.000000000',
#        '2016-01-01T02:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#     number      int64 ...
#   * time        (time) datetime64[ns] 2016-01-01 ... 2016-01-01T02:00:00
#     step        timedelta64[ns] ...
#     surface     float64 ...
#     valid_time  (time) datetime64[ns] ...
# Attributes:
#     long_name:      initial time of forecast
#     standard_name:  forecast_reference_time

# %%
[f'{i:02d}:00:00' for i in range(24)]
# Out:
# ['00:00:00',
#  '01:00:00',
#  '02:00:00',
#  '03:00:00',
#  '04:00:00',
#  '05:00:00',
#  '06:00:00',
#  '07:00:00',
#  '08:00:00',
#  '09:00:00',
#  '10:00:00',
#  '11:00:00',
#  '12:00:00',
#  '13:00:00',
#  '14:00:00',
#  '15:00:00',
#  '16:00:00',
#  '17:00:00',
#  '18:00:00',
#  '19:00:00',
#  '20:00:00',
#  '21:00:00',
#  '22:00:00',
#  '23:00:00']
