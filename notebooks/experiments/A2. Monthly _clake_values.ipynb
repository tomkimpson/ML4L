# %% [markdown]
# # Are the monthly clake values always greater than the V20 cl values?

# %%
import glob
import xarray as xr
    
root = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/' 
path_to_monthly_clake_files = f'{root}BonusClimate/'
path_to_V20_cl = f'{root}climate.v020/climate.v020/639l_2/clake'   
    
    
cl_V20= xr.open_dataset(path_to_V20_cl,engine='cfgrib',backend_kwargs={'indexpath': ''}) 
display(cl_V20)
# Out:
# <xarray.Dataset>
# Dimensions:     (values: 542080)
# Coordinates:
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     surface     float64 ...
#     latitude    (values) float64 ...
#     longitude   (values) float64 ...
#     valid_time  datetime64[ns] ...
# Dimensions without coordinates: values
# Data variables:
#     cl          (values) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2022-05-26T10:55 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
monthly_clake_files = sorted(glob.glob(path_to_monthly_clake_files+'clake*'))
        
for m in monthly_clake_files:
    print(m)
    cl_monthly = xr.open_dataset(m,engine='cfgrib',backend_kwargs={'indexpath': ''}) 
    
    delta = cl_monthly - cl_V20
    print ('MINIMUM:', delta.cl.min())
    
            #Rename the parameter so everything is not cldiff
        #    ds_clake = ds_clake.cl.rename(f'clake_monthly_value') #This is now a dataarray
            
            #Fix the time to be an integer
         #   ds_clake['time'] = month_counter #i.e. what month it it? An integer between 1 and 12
            
            
            #Append this to dataset
          #  self.monthly_clake_ds[f"month_{month_counter}"] = ds_clake 
           # month_counter += 1
# Out:
# /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/BonusClimate/clake_639l2_month01
# MINIMUM: <xarray.DataArray 'cl' ()>
# array(-0.06253171, dtype=float32)
# Coordinates:
#     time        datetime64[ns] 2011-01-31
#     step        timedelta64[ns] 00:00:00
#     surface     float64 0.0
#     valid_time  datetime64[ns] 2011-01-31
# /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/BonusClimate/clake_639l2_month02
# MINIMUM: <xarray.DataArray 'cl' ()>
# array(-0.06136334, dtype=float32)
# Coordinates:
#     time        datetime64[ns] 2011-01-31
#     step        timedelta64[ns] 00:00:00
#     surface     float64 0.0
#     valid_time  datetime64[ns] 2011-01-31
# /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/BonusClimate/clake_639l2_month03
# MINIMUM: <xarray.DataArray 'cl' ()>
# array(-0.06187379, dtype=float32)
# Coordinates:
#     time        datetime64[ns] 2011-01-31
#     step        timedelta64[ns] 00:00:00
# ...
