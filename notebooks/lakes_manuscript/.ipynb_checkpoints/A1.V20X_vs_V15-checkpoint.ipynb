# %% [markdown]
# # This notebook compares the V15 and V20 prediction errors for different bitstrings

# %% [markdown]
# #### Load the data

# %%
import pandas as pd
df = pd.read_pickle('tmp_data/clean_yearly_data.pkl')

# %% [markdown]
# #### Create a plotting function

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import cartopy.crs as ccrs
import matplotlib.colors as mc
import matplotlib.colorbar as cb 


def RobinsonPlot(df,z,vmin,vmax,cmap,markersize,savefig,ncircles):


    #Setup plotting env
    fig = plt.figure(figsize=[30,20])
    ax = plt.subplot(projection=ccrs.Robinson(central_longitude=0))
    cax = fig.add_axes([0.32, 0.11, 0.4, 0.0125])

    #Get data
    x = df['latitude_ERA']
    y = df['longitude_ERA']
    z1 = df[z]
    
    
    #Normalise
    norm = mc.Normalize(vmin=vmin, vmax=vmax)

    #Colorbar
    cb1 = cb.ColorbarBase(cax, cmap=cmap,
                               norm=norm,
                               orientation='horizontal'
                               )
    #Scatter points
    sc = ax.scatter(y,x,transform=ccrs.PlateCarree(),
                    s=markersize,
                    c=cmap(norm(z1)),
                    linewidths=1, 
                    alpha=.7)


    #Latitude cutoffs
    ax.plot([-180,180],[70,70],transform=ccrs.PlateCarree(),c='0.5', linestyle='--')
    ax.plot([-180,180],[-70,-70],transform=ccrs.PlateCarree(),c='0.5', linestyle='--')


    
    #Formatting
    cax.tick_params(labelsize=30)
    cax.set_xlabel(r'$\delta$K',fontsize=34)
    

    ax.coastlines()
    ax.set_aspect('auto') #Force projection aspect ratio
    
    ax.scatter(180,0,c='1',transform=ccrs.PlateCarree(),s=100,alpha=0.1) #invisible point to set plot limits. Hacky, but works OK.
    ax.scatter(-180,0,c='1',transform=ccrs.PlateCarree(),s=100,alpha=0.1) #invisible point to set plot limits. Hacky, but works OK.

    
    
    
    #Extra circles
    row = df.sort_values(by=['delta'],ascending=False).iloc[0:ncircles]
    xsel = row['latitude_ERA']
    ysel = row['longitude_ERA']
    
    sc_extra = ax.scatter(ysel,xsel,transform=ccrs.PlateCarree(),
                          s=200, facecolors='none', edgecolors='C2',lw=2
                          )

    if savefig is not None:
        plt.savefig(savefig,bbox_inches='tight', pad_inches=0, dpi=300)

# %%
df.columns
# Out:
# Index(['latitude_ERA', 'longitude_ERA', 'MODIS_LST', 'V15_prediction',
#        'V20_prediction', 'V20X_prediction', 'V15_error', 'V20_error',
#        'V20X_error', 'delta', 'deltaX', 'latitude_join', 'longitude_join',
#        'latitude_ERA_y', 'longitude_ERA_y', 'V15_clFr', 'V15_cvhFr',
#        'V15_cvlFr', 'V15_dl', 'V15_oceanFr', 'V15_si10Fr', 'V15_z', 'V20_clFr',
#        'V20_cvhFr', 'V20_cvlFr', 'V20_dl', 'V20_oceanFr', 'V20_si10Fr',
#        'V20_z', 'changeAbs_V20V15_clFr', 'changeAbs_V20V15_cvhFr',
#        'changeAbs_V20V15_cvlFr', 'changeAbs_V20V15_oceanFr',
#        'changeAbs_V20V15_si10Fr', 'changeAbs_V20V15_dl', 'changeAbs_V20V15_z',
#        'clFr_change_is_significant', 'cvhFr_change_is_significant',
#        'cvlFr_change_is_significant', 'oceanFr_change_is_significant',
#        'si10Fr_change_is_significant', 'dl_change_is_significant',
#        'z_change_is_significant', 'bitstring'],
#       dtype='object')

# %% [markdown]
# # 1. Lakes

# %%
df_lake = df.query('clFr_change_is_significant & dl_change_is_significant & not oceanFr_change_is_significant')
n = 5
RobinsonPlot(df_lake,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)
display(df_lake.sort_values(by=['delta'],ascending=False).iloc[0:n][['latitude_ERA','longitude_ERA','delta']])
display(df_lake.delta.mean())
display(len(df_lake))
# Out:
#         latitude_ERA  longitude_ERA     delta
# 38367      -2.388758        36.0000  5.396403
# 2272      -54.660397       -69.3750  2.445374
# 9220      -29.367672       139.6875  1.786335
# 101073     41.170945      -113.4000  1.784719
# 84857      31.615914        61.1200  1.663431
# -0.44474867
# 1650

# %%
df_lake_ground = df.query('clFr_change_is_significant & dl_change_is_significant & not oceanFr_change_is_significant & not cvhFr_change_is_significant & not cvlFr_change_is_significant')
n = 5
RobinsonPlot(df_lake_ground,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)
display(df_lake_ground.sort_values(by=['delta'],ascending=False).iloc[0:n][['latitude_ERA','longitude_ERA','delta']])
display(df_lake_ground.delta.mean())
display(len(df_lake_ground))
# Out:
#         latitude_ERA  longitude_ERA     delta
# 101073     41.170945        -113.40  1.784719
# 84857      31.615914          61.12  1.663431
# 71526      24.028095          69.00  1.604342
# 70081      23.185004          30.90  1.562348
# 100570     40.889915        -113.76  1.491879
# -1.1247547
# 546

# %% [markdown]
# # 2. Vegetation

# %%
df_veg = df.query('cvhFr_change_is_significant & not clFr_change_is_significant')
n = 5
RobinsonPlot(df_veg,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)
display(df_veg.sort_values(by=['delta'],ascending=False).iloc[0:n][['latitude_ERA','longitude_ERA','delta']])
display(df_veg.delta.mean())
display(len(df_veg))
# Out:
#         latitude_ERA  longitude_ERA     delta
# 30656      -8.852456     120.656250  4.530539
# 105108     43.419187      -4.125000  3.734607
# 86233      32.459005      34.880000  3.441413
# 54269      11.662760     102.937500  3.095105
# 3462      -42.576096     171.111111  2.250091
# 0.4946728
# 58

# %% [markdown]
# # 3. Glacier

# %%
df_ice = df.query('si10Fr_change_is_significant ')
n = 5
RobinsonPlot(df_ice,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)
display(df_ice.sort_values(by=['delta'],ascending=False).iloc[0:n][['latitude_ERA','longitude_ERA','delta']])
display(df_ice.delta.mean())
display(len(df_ice))
# Out:
#       latitude_ERA  longitude_ERA     delta
# 2328    -54.098337     -36.900000  3.715223
# 2174    -63.934391     -58.200000  3.533224
# 1903    -66.744690     109.333333  2.966166
# 2214    -61.967180     -57.937500  2.895869
# 6228    -33.021066     -70.080000  2.674545
# -0.13505524
# 1057

# %% [markdown]
# # 4. Deep dive
#
# Let look at some particular points in each of the categories

# %% [markdown]
# ----
#
#
#
#
#
#
#
# # OLD STUFF:

# %% [markdown]
# ## Bitstring 100110

# %%
df_1100110 = df.query('bitstring == "100110"')

# %%
RobinsonPlot(df_1100110,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig='figs/bitstring_100110.png',ncircles=5)

# %% [markdown]
# #### Check out some of the worst points - these are mentioned in the manuscript

# %%
ivals = [0,1,2,3,4]  # #Gujarat, Salt lake city, Peru, Northern Algeria,Australia
i = 1
df_1100110.sort_values(by=['delta'],ascending=False).iloc[i]
# Out:
# latitude_ERA                        41.170945
# longitude_ERA                          -113.4
# MODIS_LST                          294.736176
# V15_prediction                     294.245392
# V20_prediction                     302.931915
# V20X_prediction                    299.788849
# V15_error                            3.573472
# V20_error                              8.4504
# V20X_error                           6.104148
# delta                                4.876928
# deltaX                               2.530676
# values                                  94518
# step                          0 days 00:00:00
# surface                                   0.0
# latitude                            41.170945
# longitude                              -113.4
# change_in_cl                        -0.530101
# V15_cl                               0.530101
# V20_cl                                    0.0
# percentage_change_in_cl                  -1.0
# heightAboveGround                        10.0
# change_in_si10                            0.0
# V15_si10                                  0.0
# V20_si10                                  0.0
# percentage_change_in_si10                 NaN
# change_in_cvh                             0.0
# V15_cvh                                   0.0
# V20_cvh                                   0.0
# percentage_change_in_cvh                  NaN
# change_in_cvl                             0.0
# V15_cvl                                   0.0
# V20_cvl                                   0.0
# percentage_change_in_cvl                  NaN
# change_in_lsm                        0.530101
# V15_lsm                              0.469899
# V20_lsm                                   1.0
# percentage_change_in_lsm             1.128116
# change_in_dl                             24.0
# V15_dl                                    3.0
# V20_dl                                   27.0
# percentage_change_in_dl                   8.0
# cl_change_is_significant                 True
# si10_change_is_significant              False
# cvh_change_is_significant               False
# cvl_change_is_significant               False
# lsm_change_is_significant                True
# dl_change_is_significant                 True
# bitstring                              100110
# Name: 101086, dtype: object

# %%
ivals = [0,1,2,3,4]  # #Gujarat, Salt lake city, Peru, Northern Algeria,Australia
i = 2
df_1100110.sort_values(by=['delta'],ascending=False).iloc[i][['latitude_ERA','longitude_ERA','MODIS_LST','V15_prediction',
       'V20_prediction', 'V20X_prediction','V15_error','V20_error','V20X_error','delta','deltaX']]
# Out:
# latitude_ERA        -6.323183
# longitude_ERA       -80.71875
# MODIS_LST          311.564301
# V15_prediction     308.391449
# V20_prediction     304.894409
# V20X_prediction    300.358093
# V15_error            4.953901
# V20_error            7.726332
# V20X_error          11.876699
# delta                 2.77243
# deltaX               6.922798
# Name: 33374, dtype: object

# %%
df_1100110.sort_values(by=['delta'],ascending=False).iloc[i].latitude_ERA
# Out:
# -15.316154469334318

# %%
df_1100110.sort_values(by=['delta'],ascending=False).iloc[i].longitude_ERA
# Out:
# 127.96875

# %% [markdown]
# ## Bitstring 000101

# %%
df_000101 = df.query('bitstring == "000101"')

# %%
RobinsonPlot(df_000101,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig='figs/bitstring_000101.png')

# %%
#Alaskan gulf point
df_000101.sort_values(by=['delta'],ascending=False).iloc[0]
# Out:
# latitude_ERA                         59.99997
# longitude_ERA                     -141.866667
# MODIS_LST                          271.977448
# V15_prediction                     277.694244
# V20_prediction                     261.428802
# V20X_prediction                    275.110748
# V15_error                            6.214495
# V20_error                           10.868941
# V20X_error                           4.763571
# delta                                4.654447
# deltaX                              -1.450924
# values                                  37428
# step                          0 days 00:00:00
# surface                                   0.0
# latitude                             59.99997
# longitude                         -141.866667
# change_in_cl                          0.00121
# V15_cl                                    0.0
# V20_cl                                0.00121
# percentage_change_in_cl                   inf
# heightAboveGround                        10.0
# change_in_si10                       0.112061
# V15_si10                             0.164856
# V20_si10                             0.276917
# percentage_change_in_si10            0.679748
# change_in_cvh                             0.0
# V15_cvh                                   0.0
# V20_cvh                                   0.0
# percentage_change_in_cvh                  NaN
# change_in_cvl                             0.0
# V15_cvl                                   0.0
# V20_cvl                                   0.0
# percentage_change_in_cvl                  NaN
# change_in_lsm                         0.08266
# V15_lsm                              0.438392
# V20_lsm                              0.521052
# percentage_change_in_lsm             0.188552
# change_in_dl                        69.787109
# V15_dl                              38.737305
# V20_dl                             108.524414
# percentage_change_in_dl              1.801548
# cl_change_is_significant                False
# si10_change_is_significant               True
# cvh_change_is_significant               False
# cvl_change_is_significant               False
# lsm_change_is_significant               False
# dl_change_is_significant                 True
# bitstring                              000101
# Name: 133962, dtype: object

# %% [markdown]
# ## Bitstring 010100

# %%
df_010100 = df.query('bitstring == "010100"')

# %%
df_010100.sort_values(by=['delta'],ascending=False)#.iloc[4]
# Out:
#         latitude_ERA  longitude_ERA   MODIS_LST  V15_prediction  \
# 141003     64.215421      23.750000  278.907043      277.626678
# 89842      34.426218     131.333333  291.155426      292.753540
# 69458      22.903974     -83.400000  301.717712      302.266846
# 105121     43.419187      -4.125000  292.058167      292.966858
# 40088      -0.983606      98.718750  299.748657      299.439484
# 4389      -37.798581     148.666667  293.302094      291.919373
# 135369     60.843060    -115.555556  272.399689      273.635132
# 44374       2.950819     112.218750  302.328308      301.873413
# 40808      -0.421546     132.187500  300.560242      297.746429
# 40928      -0.140515     -50.062500  301.993317      306.742126
# 54271      11.662760     102.937500  302.128815      301.170654
# 38577      -2.107728     -54.000000  301.163452      305.001984
# 86246      32.459005      34.880000  303.553070      304.888947
#
#         V20_prediction  V20X_prediction  V15_error  V20_error  V20X_error  \
# 141003      292.306549       279.692169   2.752890  13.399515    2.786702
# 89842       303.266937       291.036896   2.277692  12.111497    2.176783
# 69458       313.267120       302.097168   1.793129  11.549413    2.049138
# 105121      303.697815       294.145721   2.170567  11.639643    2.540581
# 40088       311.325012       300.483948   2.597664  11.576346    2.598799
# 4389        304.229431       295.274445   2.645613  10.927361    2.912897
# 135369      282.455261       271.013031   2.559674  10.070865    3.953590
# 44374       311.749878       301.558868   2.602192   9.421556    2.369967
# 40808       310.297333       300.102692   3.412266   9.773700    2.084944
# 40928       312.982605       301.182617   4.794086  10.989294    2.396937
# 54271       310.106628       301.548187   2.352256   7.994905    2.430140
# 38577       310.202728       301.280975   3.878059   9.039287    1.625511
# 86246       310.035553       302.497620   2.516774   6.489748    2.654187
#
#             delta  ...     V15_dl      V20_dl percentage_change_in_dl  \
# 141003  10.646625  ...  25.000000   12.540039               -0.498398
# 89842    9.833805  ...  25.000000   33.124023                0.324961
# 69458    9.756284  ...  25.000000  298.899414               10.955976
# 105121   9.469076  ...  25.000000  240.665039                8.626601
# 40088    8.978683  ...  25.000000  128.749023                4.149961
# 4389     8.281747  ...  25.000000   33.034180                0.321367
# 135369   7.511190  ...  10.425781   16.338867                0.567160
# 44374    6.819364  ...  25.000000    7.783203               -0.688672
# 40808    6.361434  ...  25.000000  573.608398               21.944336
# 40928    6.195209  ...  25.000000    9.286133               -0.628555
# 54271    5.642650  ...  25.000000   10.099609               -0.596016
# 38577    5.161228  ...   3.000000   10.000000                2.333333
# 86246    3.972974  ...  25.000000   41.237305                0.649492
#
#         cl_change_is_significant  si10_change_is_significant  \
# 141003                     False                       False
# 89842                      False                       False
# 69458                      False                       False
# 105121                     False                       False
# 40088                      False                       False
# 4389                       False                       False
# 135369                     False                       False
# 44374                      False                       False
# 40808                      False                       False
# 40928                      False                       False
# 54271                      False                       False
# 38577                      False                       False
# 86246                      False                       False
#
#         cvh_change_is_significant  cvl_change_is_significant  \
# 141003                       True                      False
# 89842                        True                      False
# 69458                        True                      False
# 105121                       True                      False
# 40088                        True                      False
# 4389                         True                      False
# 135369                       True                      False
# 44374                        True                      False
# 40808                        True                      False
# 40928                        True                      False
# 54271                        True                      False
# 38577                        True                      False
# 86246                        True                      False
#
#         lsm_change_is_significant  dl_change_is_significant  bitstring
# 141003                      False                      True     010100
# 89842                       False                      True     010100
# 69458                       False                      True     010100
# 105121                      False                      True     010100
# 40088                       False                      True     010100
# 4389                        False                      True     010100
# 135369                      False                      True     010100
# 44374                       False                      True     010100
# 40808                       False                      True     010100
# 40928                       False                      True     010100
# 54271                       False                      True     010100
# 38577                       False                      True     010100
# 86246                       False                      True     010100
#
# [13 rows x 48 columns]
