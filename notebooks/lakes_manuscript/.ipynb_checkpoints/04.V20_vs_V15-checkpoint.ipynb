# %% [markdown]
# # This notebook compares the V15 and V20 prediction errors for different bitstrings

# %% [markdown]
# #### Load the data

# %%
import pandas as pd
df = pd.read_pickle('tmp_data/clean_yearly_data.pkl')

# %% [markdown]
# #### Create a plotting function

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import cartopy.crs as ccrs
import matplotlib.colors as mc
import matplotlib.colorbar as cb 


def RobinsonPlot(df,z,vmin,vmax,cmap,markersize,savefig,ncircles):


    #Setup plotting env
    fig = plt.figure(figsize=[30,20])
    ax = plt.subplot(projection=ccrs.Robinson(central_longitude=0))
    cax = fig.add_axes([0.32, 0.11, 0.4, 0.0125])

    #Get data
    x = df['latitude_ERA']
    y = df['longitude_ERA']
    z1 = df[z]
    
    
    #Normalise
    norm = mc.Normalize(vmin=vmin, vmax=vmax)

    #Colorbar
    cb1 = cb.ColorbarBase(cax, cmap=cmap,
                               norm=norm,
                               orientation='horizontal'
                               )
    #Scatter points
    sc = ax.scatter(y,x,transform=ccrs.PlateCarree(),
                    s=markersize,
                    c=cmap(norm(z1)),
                    linewidths=1, 
                    alpha=.7)


    #Latitude cutoffs
    ax.plot([-180,180],[70,70],transform=ccrs.PlateCarree(),c='0.5', linestyle='--')
    ax.plot([-180,180],[-70,-70],transform=ccrs.PlateCarree(),c='0.5', linestyle='--')


    
    #Formatting
    cax.tick_params(labelsize=30)
    cax.set_xlabel(r'$\delta$K',fontsize=34)
    

    ax.coastlines()
    ax.set_aspect('auto') #Force projection aspect ratio
    
    ax.scatter(180,0,c='1',transform=ccrs.PlateCarree(),s=100,alpha=0.1) #invisible point to set plot limits. Hacky, but works OK.
    ax.scatter(-180,0,c='1',transform=ccrs.PlateCarree(),s=100,alpha=0.1) #invisible point to set plot limits. Hacky, but works OK.

    
    
    
    #Extra circles
    row = df.sort_values(by=['delta'],ascending=False).iloc[0:ncircles]
    xsel = row['latitude_ERA']
    ysel = row['longitude_ERA']
    
    sc_extra = ax.scatter(ysel,xsel,transform=ccrs.PlateCarree(),
                          s=200, facecolors='none', edgecolors='C2',lw=2
                          )

    if savefig is not None:
        plt.savefig(savefig,bbox_inches='tight', pad_inches=0, dpi=300)

# %%
df.columns
# Out:
# Index(['latitude_ERA', 'longitude_ERA', 'MODIS_LST', 'V15_prediction',
#        'V20_prediction', 'V20X_prediction', 'V15_error', 'V20_error',
#        'V20X_error', 'delta', 'deltaX', 'latitude_join', 'longitude_join',
#        'latitude_ERA_y', 'longitude_ERA_y', 'V15_clFr', 'V15_cvhFr',
#        'V15_cvlFr', 'V15_dl', 'V15_oceanFr', 'V15_si10Fr', 'V15_z', 'V20_clFr',
#        'V20_cvhFr', 'V20_cvlFr', 'V20_dl', 'V20_oceanFr', 'V20_si10Fr',
#        'V20_z', 'changeAbs_V20V15_clFr', 'changeAbs_V20V15_cvhFr',
#        'changeAbs_V20V15_cvlFr', 'changeAbs_V20V15_oceanFr',
#        'changeAbs_V20V15_si10Fr', 'changeAbs_V20V15_dl', 'changeAbs_V20V15_z',
#        'clFr_change_is_significant', 'cvhFr_change_is_significant',
#        'cvlFr_change_is_significant', 'oceanFr_change_is_significant',
#        'si10Fr_change_is_significant', 'dl_change_is_significant',
#        'z_change_is_significant', 'bitstring'],
#       dtype='object')

# %% [markdown]
# # 1. Lakes

# %%
df_lake = df.query('clFr_change_is_significant & dl_change_is_significant & not oceanFr_change_is_significant & not si10Fr_change_is_significant')
n = 7
RobinsonPlot(df_lake,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig='figs/lake_haver.png',ncircles=n)
display(df_lake.sort_values(by=['delta'],ascending=False).iloc[0:n][['latitude_ERA','longitude_ERA','delta']])
display(df_lake.delta.mean())
display(len(df_lake)) #''
# Out:
#         latitude_ERA  longitude_ERA     delta
# 38367      -2.388758        36.0000  5.396403
# 9220      -29.367672       139.6875  1.786335
# 101073     41.170945      -113.4000  1.784719
# 84857      31.615914        61.1200  1.663431
# 38705      -2.107728        36.0000  1.659139
# 71526      24.028095        69.0000  1.604342
# 70081      23.185004        30.9000  1.562348
# -0.45003444
# 1631

# %%
df_lake_ground = df.query('clFr_change_is_significant & dl_change_is_significant & not oceanFr_change_is_significant & not cvhFr_change_is_significant & not cvlFr_change_is_significant')
n = 5
RobinsonPlot(df_lake_ground,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)
display(df_lake_ground.sort_values(by=['delta'],ascending=False).iloc[0:n][['latitude_ERA','longitude_ERA','delta']])
display(df_lake_ground.delta.mean())
display(len(df_lake_ground))
# Out:
#         latitude_ERA  longitude_ERA     delta
# 101073     41.170945        -113.40  1.784719
# 84857      31.615914          61.12  1.663431
# 71526      24.028095          69.00  1.604342
# 70081      23.185004          30.90  1.562348
# 100570     40.889915        -113.76  1.491879
# -1.1247547
# 546

# %% [markdown]
# # 2. Vegetation

# %%
df_veg = df.query('cvhFr_change_is_significant & not cvlFr_change_is_significant')
n = 5
RobinsonPlot(df_veg,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)
display(df_veg.sort_values(by=['delta'],ascending=False).iloc[0:n][['latitude_ERA','longitude_ERA','delta']])
display(df_veg.delta.mean())
display(len(df_veg))
# Out:
#         latitude_ERA  longitude_ERA     delta
# 30656      -8.852456     120.656250  4.530539
# 105108     43.419187      -4.125000  3.734607
# 86233      32.459005      34.880000  3.441413
# 54269      11.662760     102.937500  3.095105
# 3462      -42.576096     171.111111  2.250091
# 0.23525162
# 78

# %%
df_veg = df.query('cvhFr_change_is_significant & not clFr_change_is_significant')
n = 5
RobinsonPlot(df_veg,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)
display(df_veg.sort_values(by=['delta'],ascending=False).iloc[0:n][['latitude_ERA','longitude_ERA','delta']])
display(df_veg.delta.mean())
display(len(df_veg))
# Out:
#         latitude_ERA  longitude_ERA     delta
# 30656      -8.852456     120.656250  4.530539
# 105108     43.419187      -4.125000  3.734607
# 86233      32.459005      34.880000  3.441413
# 54269      11.662760     102.937500  3.095105
# 3462      -42.576096     171.111111  2.250091
# 0.4946728
# 58

# %% [markdown]
# # 3. Glacier

# %%
df_ice = df.query('si10Fr_change_is_significant ')
n = 5
RobinsonPlot(df_ice,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)
display(df_ice.sort_values(by=['delta'],ascending=False).iloc[0:n][['latitude_ERA','longitude_ERA','delta']])
display(df_ice.delta.mean())
display(len(df_ice))
# Out:
#       latitude_ERA  longitude_ERA     delta
# 2328    -54.098337     -36.900000  3.715223
# 2174    -63.934391     -58.200000  3.533224
# 1903    -66.744690     109.333333  2.966166
# 2214    -61.967180     -57.937500  2.895869
# 6228    -33.021066     -70.080000  2.674545
# -0.13505524
# 1057

# %% [markdown]
# # 4. Deep dive
#
# Let look at some particular points in each of the categories
#
# ## 4a. Lakes

# %%
display(df_lake.sort_values(by=['delta'],ascending=False).iloc[0:7][['latitude_ERA','longitude_ERA','delta']])
display(df_lake.delta.mean())
display(len(df_lake))
# Out:
#         latitude_ERA  longitude_ERA     delta
# 38367      -2.388758        36.0000  5.396403
# 9220      -29.367672       139.6875  1.786335
# 101073     41.170945      -113.4000  1.784719
# 84857      31.615914        61.1200  1.663431
# 38705      -2.107728        36.0000  1.659139
# 71526      24.028095        69.0000  1.604342
# 70081      23.185004        30.9000  1.562348
# -0.45003444
# 1631

# %%
#0 = Lake natron, 
#1 = Australia
#2= SLC
#3=Afghan/Iran
#4 = Lake natron, northern edge
#5 = Northern India
#6 = Toska Lakes
i = 6
display(df_lake.sort_values(by=['delta'],ascending=False).iloc[i])
display(df_lake.sort_values(by=['delta'],ascending=False).iloc[i][['latitude_ERA']].values[0])
display(df_lake.sort_values(by=['delta'],ascending=False).iloc[i][['longitude_ERA']])
# Out:
# latitude_ERA                       23.185004
# longitude_ERA                           30.9
# MODIS_LST                         318.107666
# V15_prediction                    316.808899
# V20_prediction                    313.785095
# V20X_prediction                   319.030121
# V15_error                           3.231364
# V20_error                           4.793711
# V20X_error                          2.552968
# delta                               1.562348
# deltaX                             -0.678396
# latitude_join                         23.185
# longitude_join                          30.9
# latitude_ERA_y                     23.185004
# longitude_ERA_y                         30.9
# V15_clFr                            0.356066
# V15_cvhFr                                0.0
# V15_cvlFr                           0.005619
# V15_dl                                  25.0
# V15_oceanFr                              0.0
# V15_si10Fr                               0.0
# V15_z                            1652.745972
# V20_clFr                                 0.0
# V20_cvhFr                                0.0
# V20_cvlFr                           0.008728
# V20_dl                              6.211914
# V20_oceanFr                              0.0
# V20_si10Fr                               0.0
# V20_z                            1638.201416
# changeAbs_V20V15_clFr               0.356066
# changeAbs_V20V15_cvhFr                   0.0
# changeAbs_V20V15_cvlFr              0.003109
# changeAbs_V20V15_oceanFr                 0.0
# changeAbs_V20V15_si10Fr                  0.0
# changeAbs_V20V15_dl                18.788086
# changeAbs_V20V15_z                 14.544556
# clFr_change_is_significant              True
# cvhFr_change_is_significant            False
# cvlFr_change_is_significant            False
# oceanFr_change_is_significant          False
# si10Fr_change_is_significant           False
# dl_change_is_significant                True
# z_change_is_significant                False
# bitstring                            1001000
# Name: 70081, dtype: object
# 23.18500423251539
# longitude_ERA    30.9
# Name: 70081, dtype: object

# %%
# Northern Canada - all points
df_lake_canada = df_lake.query('50.0 < latitude_ERA & -130 < longitude_ERA < -80')
RobinsonPlot(df_lake_canada,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)
display(df_lake_canada.delta.mean())
# Out:
# 0.017366955

# %%
# Northern Canada - bad points
df_lake_canada_bad = df_lake.query('delta > 0 & 50.0 < latitude_ERA & -130 < longitude_ERA < -80')
RobinsonPlot(df_lake_canada_bad,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)
display(df_lake_canada_bad.delta.mean())
display(df_lake.sort_values(by=['delta'],ascending=False).iloc[3])
# Out:
# 0.12237371
# latitude_ERA                       31.615914
# longitude_ERA                          61.12
# MODIS_LST                         312.860474
# V15_prediction                    313.586182
# V20_prediction                    317.005798
# V20X_prediction                   314.404816
# V15_error                           2.962719
# V20_error                           4.626151
# V20X_error                          2.923563
# delta                               1.663431
# deltaX                             -0.039156
# latitude_join                         31.616
# longitude_join                         61.12
# latitude_ERA_y                     31.615914
# longitude_ERA_y                    61.119999
# V15_clFr                            0.112399
# V15_cvhFr                                0.0
# V15_cvlFr                           0.003856
# V15_dl                                   8.0
# V15_oceanFr                              0.0
# V15_si10Fr                               0.0
# V15_z                            5823.691406
# V20_clFr                                 0.0
# V20_cvhFr                                0.0
# V20_cvlFr                           0.004333
# V20_dl                              9.820312
# V20_oceanFr                              0.0
# V20_si10Fr                               0.0
# V20_z                            5823.126953
# changeAbs_V20V15_clFr               0.112399
# changeAbs_V20V15_cvhFr                   0.0
# changeAbs_V20V15_cvlFr              0.000477
# changeAbs_V20V15_oceanFr                 0.0
# changeAbs_V20V15_si10Fr                  0.0
# changeAbs_V20V15_dl                 1.820312
# changeAbs_V20V15_z                  0.564453
# clFr_change_is_significant              True
# cvhFr_change_is_significant            False
# cvlFr_change_is_significant            False
# oceanFr_change_is_significant          False
# si10Fr_change_is_significant           False
# dl_change_is_significant                True
# z_change_is_significant                False
# bitstring                            1001000
# Name: 84857, dtype: object

# %%
# Northern Canada - good points
df_lake_canada_good = df_lake.query('delta < 0 & 50.0 < latitude_ERA & -130 < longitude_ERA < -80')
RobinsonPlot(df_lake_canada_good,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)
display(df_lake_canada_good.delta.mean())
display(df_lake.sort_values(by=['delta'],ascending=True).iloc[0])
# Out:
# -0.10772805
# latitude_ERA                      -28.24355
# longitude_ERA                      137.1875
# MODIS_LST                        313.954041
# V15_prediction                   294.568146
# V20_prediction                   312.078827
# V20X_prediction                  309.996826
# V15_error                         19.385876
# V20_error                          4.199694
# V20X_error                         5.027334
# delta                            -15.186182
# deltaX                           -14.358541
# latitude_join                       -28.244
# longitude_join                      137.188
# latitude_ERA_y                    -28.24355
# longitude_ERA_y                    137.1875
# V15_clFr                           0.998833
# V15_cvhFr                               0.0
# V15_cvlFr                               0.0
# V15_dl                              4.69043
# V15_oceanFr                             0.0
# V15_si10Fr                              0.0
# V15_z                           -158.472778
# V20_clFr                                0.0
# V20_cvhFr                               0.0
# V20_cvlFr                               0.0
# V20_dl                                  1.0
# V20_oceanFr                             0.0
# V20_si10Fr                              0.0
# V20_z                           -158.142334
# changeAbs_V20V15_clFr              0.998833
# changeAbs_V20V15_cvhFr                  0.0
# changeAbs_V20V15_cvlFr                  0.0
# changeAbs_V20V15_oceanFr                0.0
# changeAbs_V20V15_si10Fr                 0.0
# changeAbs_V20V15_dl                 3.69043
# changeAbs_V20V15_z                 0.330444
# clFr_change_is_significant             True
# cvhFr_change_is_significant           False
# cvlFr_change_is_significant           False
# oceanFr_change_is_significant         False
# si10Fr_change_is_significant          False
# dl_change_is_significant               True
# z_change_is_significant               False
# bitstring                           1001000
# Name: 10217, dtype: object

# %%
import seaborn as sns


df_lake_canada_good['change_in_cl'] = df_lake_canada_good['V15_clFr'] - df_lake_canada_good['V20_clFr']
df_lake_canada_good['change_in_cvl'] = df_lake_canada_good['V15_cvlFr'] - df_lake_canada_good['V20_cvlFr']
df_lake_canada_good['change_in_cvh'] = df_lake_canada_good['V15_cvhFr'] - df_lake_canada_good['V20_cvhFr']

df_lake_canada_bad['change_in_cl'] = df_lake_canada_bad['V15_clFr'] - df_lake_canada_bad['V20_clFr']
df_lake_canada_bad['change_in_cvl'] = df_lake_canada_bad['V15_cvlFr'] - df_lake_canada_bad['V20_cvlFr']
df_lake_canada_bad['change_in_cvh'] = df_lake_canada_bad['V15_cvhFr'] - df_lake_canada_bad['V20_cvhFr']
# Out:
# /home/k/kimpson/bin/conda/envs/workhorse/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/k/kimpson/bin/conda/envs/workhorse/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/k/kimpson/bin/conda/envs/workhorse/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/k/kimpson/bin/conda/envs/workhorse/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/k/kimpson/bin/conda/envs/workhorse/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /home/k/kimpson/bin/conda/envs/workhorse/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
plt.plot()
plt.scatter(df_lake_canada_good['change_in_cl'],df_lake_canada_good['delta'])
plt.scatter(df_lake_canada_bad['change_in_cl'],df_lake_canada_bad['delta'])




#sns.scatterplot(df_lake_canada_good,'change_in_cl','change_in_cl')

# %%
plt.plot()
plt.scatter(df_lake_canada_good['change_in_cvl'],df_lake_canada_good['delta'])
plt.scatter(df_lake_canada_bad['change_in_cvl'],df_lake_canada_bad['delta'])

# %%
plt.plot()
plt.scatter(df_lake_canada_good['change_in_cvh'],df_lake_canada_good['delta'])
plt.scatter(df_lake_canada_bad['change_in_cvh'],df_lake_canada_bad['delta'])

# %%
# Edge of Caspian sea

df_lake_bad = df_lake.query('delta > 0.0 &   46 < latitude_ERA < 54 & 43 < longitude_ERA < 53')
RobinsonPlot(df_lake_bad,'delta',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None,ncircles=n)

# %%
df_lake_bad.delta.mean()
len(df_lake_bad) #.delta.mean()
# Out:
# 4

# %%
display(df_lake_bad.sort_values(by=['delta'],ascending=False).iloc[3])
# Out:
# latitude_ERA                      47.072581
# longitude_ERA                          51.6
# MODIS_LST                        299.135193
# V15_prediction                   297.250397
# V20_prediction                   297.190613
# V20X_prediction                  298.770691
# V15_error                           3.54242
# V20_error                          3.701699
# V20X_error                         3.380102
# delta                              0.159278
# deltaX                            -0.162318
# latitude_join                        47.073
# longitude_join                         51.6
# latitude_ERA_y                    47.072581
# longitude_ERA_y                   51.599998
# V15_clFr                           0.208708
# V15_cvhFr                          0.027408
# V15_cvlFr                          0.677959
# V15_dl                            18.993164
# V15_oceanFr                             0.0
# V15_si10Fr                              0.0
# V15_z                           -280.011841
# V20_clFr                           0.051947
# V20_cvhFr                          0.032838
# V20_cvlFr                          0.812274
# V20_dl                             1.445312
# V20_oceanFr                             0.0
# V20_si10Fr                              0.0
# V20_z                           -280.415771
# changeAbs_V20V15_clFr              0.156761
# changeAbs_V20V15_cvhFr              0.00543
# changeAbs_V20V15_cvlFr             0.134315
# changeAbs_V20V15_oceanFr                0.0
# changeAbs_V20V15_si10Fr                 0.0
# changeAbs_V20V15_dl               17.547852
# changeAbs_V20V15_z                 0.403931
# clFr_change_is_significant             True
# cvhFr_change_is_significant           False
# cvlFr_change_is_significant            True
# oceanFr_change_is_significant         False
# si10Fr_change_is_significant          False
# dl_change_is_significant               True
# z_change_is_significant               False
# bitstring                           1011000
# change_in_cl                       0.156761
# change_in_cvl                     -0.134315
# change_in_cvh                      -0.00543
# Name: 112051, dtype: object

# %%
df_lake_bad['change_in_cl'] = df_lake_bad['V15_clFr'] - df_lake_bad['V20_clFr']
df_lake_bad['change_in_cvl'] = df_lake_bad['V15_cvlFr'] - df_lake_bad['V20_cvlFr']
df_lake_bad['change_in_cvh'] = df_lake_bad['V15_cvhFr'] - df_lake_bad['V20_cvhFr']
# Out:
# /home/k/kimpson/bin/conda/envs/workhorse/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/k/kimpson/bin/conda/envs/workhorse/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/k/kimpson/bin/conda/envs/workhorse/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.plot()
plt.scatter(df_lake_bad['change_in_cl'],df_lake_bad['delta'])
plt.scatter(df_lake_bad['change_in_cl'],df_lake_bad['delta'])




#sns.scatterplot(df_lake_canada_good,'change_in_cl','change_in_cl')

# %% [markdown]
# ---

# %% [markdown]
# # Vegetation deep dive

# %%
display(df_veg.sort_values(by=['delta'],ascending=False).iloc[0:n][['latitude_ERA','longitude_ERA','delta']])
display(df_veg.sort_values(by=['delta'],ascending=False).iloc[1])
# Out:
#         latitude_ERA  longitude_ERA     delta
# 30656      -8.852456     120.656250  4.530539
# 105108     43.419187      -4.125000  3.734607
# 86233      32.459005      34.880000  3.441413
# 54269      11.662760     102.937500  3.095105
# 3462      -42.576096     171.111111  2.250091
# latitude_ERA                      43.419187
# longitude_ERA                        -4.125
# MODIS_LST                        292.058167
# V15_prediction                   292.267761
# V20_prediction                    286.69754
# V20X_prediction                  294.884979
# V15_error                          1.977671
# V20_error                          5.712278
# V20X_error                         3.197525
# delta                              3.734607
# deltaX                             1.219854
# latitude_join                        43.419
# longitude_join                       -4.125
# latitude_ERA_y                    43.419187
# longitude_ERA_y                      -4.125
# V15_clFr                                0.0
# V15_cvhFr                          0.340553
# V15_cvlFr                          0.031589
# V15_dl                                 25.0
# V15_oceanFr                        0.490701
# V15_si10Fr                              0.0
# V15_z                            575.105347
# V20_clFr                           0.002106
# V20_cvhFr                               0.0
# V20_cvlFr                               0.0
# V20_dl                            240.66504
# V20_oceanFr                        0.498279
# V20_si10Fr                              0.0
# V20_z                            431.818604
# changeAbs_V20V15_clFr              0.002106
# changeAbs_V20V15_cvhFr             0.340553
# changeAbs_V20V15_cvlFr             0.031589
# changeAbs_V20V15_oceanFr           0.007578
# changeAbs_V20V15_si10Fr                 0.0
# changeAbs_V20V15_dl              215.665039
# changeAbs_V20V15_z               143.286743
# clFr_change_is_significant            False
# cvhFr_change_is_significant            True
# cvlFr_change_is_significant           False
# oceanFr_change_is_significant         False
# si10Fr_change_is_significant          False
# dl_change_is_significant               True
# z_change_is_significant                True
# bitstring                           0101001
# Name: 105108, dtype: object

# %%
df_tmp = df_veg.copy()
df_tmp['change_in_cvh'] = df_tmp['V15_cvhFr'] - df_tmp['V20_cvhFr']

# %%
plt.plot(figsize=(24,16))
plt.scatter(df_tmp['change_in_cvh'],df_tmp['delta'])
plt.axhline(0.0)
plt.axvline(0.0)



#sns.scatterplot(df_lake_canada_good,'change_in_cl','change_in_cl')

# %%
oddballs = df_tmp.query('change_in_cvh < 0 & delta > 0')

# %%
oddballs
# Out:
#         latitude_ERA  longitude_ERA   MODIS_LST  V15_prediction  \
# 138039      62.52924    -141.750000  273.655884      275.360626
# 138055      62.52924    -132.750000  273.284637      273.250610
# 144957      66.74469    -150.666667  271.204254      270.628235
#
#         V20_prediction  V20X_prediction  V15_error  V20_error  V20X_error  \
# 138039      275.702911       275.700439   3.300290   3.395012    3.202509
# 138055      273.559845       273.468964   2.344465   2.510466    2.268356
# 144957      270.932831       270.848938   3.161345   3.550501    3.218453
#
#            delta  ...  changeAbs_V20V15_z  clFr_change_is_significant  \
# 138039  0.094722  ...            0.783203                        True
# 138055  0.166001  ...           14.986328                        True
# 144957  0.389157  ...            2.326416                        True
#
#         cvhFr_change_is_significant  cvlFr_change_is_significant  \
#
# 95204   1.045430  ...           19.958618                       False
# 96350   0.877097  ...            7.032837                        True
# 105108  3.734607  ...          143.286743                       False
# 121361  0.088083  ...            1.799072                        True
# 134447  0.086636  ...            1.689697                        True
# 134472  0.381814  ...            0.864990                       False
# 134925  0.070554  ...            2.459229                        True
# 135352  1.265734  ...           10.376587                       False
# 138039  0.094722  ...            0.783203                        True
# 138055  0.166001  ...           14.986328                        True
# 140986  1.037153  ...            8.841431                       False
# 144957  0.389157  ...            2.326416                        True
# 146649  0.043996  ...            1.325806                        True
#
#         cvhFr_change_is_significant  cvlFr_change_is_significant  \
# 2695                           True                        False
# 2722                           True                        False
# 2771                           True                        False
# 2844                           True                        False
# 2968                           True                        False
# 3145                           True                        False
# 3182                           True                        False
# 3300                           True                        False
# 3301                           True                        False
# 3384                           True                        False
# 3462                           True                        False
# 4389                           True                        False
# 19009                          True                        False
# 30656                          True                        False
# 40086                          True                        False
# 40806                          True                        False
# 42655                          True                        False
# 43812                          True                        False
# 44099                          True                        False
# 44101                          True                        False
# 44372                          True                        False
# 54269                          True                        False
# 69456                          True                        False
# 86233                          True                        False
# 89829                          True                        False
# 95204                          True                        False
# 96350                          True                        False
# 105108                         True                        False
# 121361                         True                        False
# 134447                         True                        False
# 134472                         True                        False
# 134925                         True                        False
# 135352                         True                        False
# 138039                         True                        False
# 138055                         True                        False
# 140986                         True                        False
# 144957                         True                        False
# 146649                         True                        False
#
#         oceanFr_change_is_significant  si10Fr_change_is_significant  \
# 2695                            False                          True
# 2722                            False                          True
# 2771                            False                          True
# 2844                            False                          True
# 2968                            False                         False
# 3145                            False                          True
# 3182                            False                          True
# 3300                            False                          True
# 3301                            False                          True
# 3384                            False                          True
# 3462                            False                         False
# 4389                            False                         False
# 19009                           False                         False
# 30656                           False                         False
# 40086                           False                         False
# 40806                           False                         False
# 42655                           False                         False
# 43812                           False                         False
# 44099                           False                         False
# 44101                           False                         False
# 44372                           False                         False
# 54269                           False                         False
# 69456                           False                         False
# 86233                           False                         False
# 89829                           False                         False
# 95204                           False                         False
# 96350                           False                         False
# 105108                          False                         False
# 121361                          False                         False
# 134447                          False                         False
# 134472                          False                         False
# 134925                          False                         False
# 135352                          False                         False
# 138039                          False                         False
# 138055                          False                         False
# 140986                          False                         False
# 144957                          False                         False
# 146649                          False                         False
#
#         dl_change_is_significant  z_change_is_significant  bitstring  \
# 2695                        True                    False    0101010
# 2722                        True                    False    0101010
# 2771                        True                    False    0101010
# 2844                        True                    False    0101010
# 2968                        True                    False    0101000
# 3145                        True                    False    0101010
# 3182                        True                    False    0101010
# 3300                        True                    False    0101010
# 3301                        True                    False    0101010
# 3384                        True                    False    0101010
# 3462                       False                     True    0100001
# 4389                        True                     True    0101001
# 19009                       True                    False    0101000
# 30656                       True                     True    0101001
# 40086                       True                     True    0101001
# 40806                       True                     True    0101001
# 42655                       True                     True    0101001
# 43812                       True                    False    1101000
# 44099                       True                    False    1101000
# 44101                       True                    False    1101000
# 44372                       True                     True    0101001
# 54269                       True                     True    0101001
# 69456                       True                     True    0101001
# 86233                       True                     True    0101001
# 89829                       True                    False    0101000
# 95204                       True                     True    0101001
# 96350                       True                    False    1101000
# 105108                      True                     True    0101001
# 121361                      True                    False    1101000
#         cvhFr_change_is_significant  cvlFr_change_is_significant  \
# 2871                           True                        False
# 2903                           True                        False
# 2933                           True                        False
# 2967                           True                        False
# 28804                          True                        False
# 29071                          True                        False
# 29347                          True                        False
# 38575                          True                        False
# 40926                          True                        False
# 44100                          True                        False
# 50056                          True                        False
# 58230                          True                        False
# 61993                          True                        False
# 70703                          True                        False
# 119619                         True                        False
# 121360                         True                        False
# 122298                         True                        False
# 122806                         True                        False
# 126718                         True                        False
# 132110                         True                        False
# 132112                         True                        False
# 132533                         True                        False
# 132535                         True                        False
# 132536                         True                        False
# 134448                         True                        False
# 134914                         True                        False
# 139025                         True                        False
# 144068                         True                        False
# 144069                         True                        False
# 146245                         True                        False
#
#         oceanFr_change_is_significant  si10Fr_change_is_significant  \
# 2871                            False                          True
# 2903                            False                         False
# 2933                            False                         False
# 2967                            False                         False
# 28804                           False                         False
# 29071                           False                         False
# 29347                           False                         False
# 38575                           False                         False
# 40926                           False                         False
# 44100                           False                         False
# 50056                           False                         False
# 58230                           False                         False
# 61993                           False                         False
# 70703                           False                         False
# 119619                          False                          True
# 121360                          False                         False
# 122298                          False                          True
# 122806                          False                          True
# 126718                          False                          True
# 132110                          False                         False
# 132112                          False                         False
# 132533                          False                         False
# 132535                          False                         False
# 132536                          False                         False
# 134448                          False                         False
# 134914                          False                         False
# 139025                          False                         False
# 144068                          False                         False
# 144069                          False                         False
# 146245                          False                         False
#
#         dl_change_is_significant  z_change_is_significant  bitstring  \
# 2871                        True                    False    1101010
# 2903                        True                    False    0101000
# 2933                        True                    False    0101000
# 2967                        True                    False    0101000
# 28804                       True                    False    1101000
# 29071                       True                    False    1101000
# 29347                       True                    False    1101000
# 38575                       True                     True    0101001
# 40926                       True                     True    0101001
# 44100                       True                    False    1101000
# 50056                       True                     True    1101001
# 58230                       True                    False    1101000
# 61993                       True                    False    1101000
# 70703                       True                    False    1101000
# 119619                     False                    False    0100010
# 121360                      True                    False    1101000
# 122298                      True                    False    0101010
# 122806                      True                    False    0101010
# 126718                      True                    False    0101010
# 132110                      True                    False    1101000
# 132112                      True                    False    1101000
# 132533                     False                    False    1100000
# 132535                     False                    False    1100000
# 132536                     False                    False    1100000
# 134448                      True                    False    1101000
# 134914                      True                    False    1101000
# 139025                      True                    False    1101000
# 144068                      True                    False    1101000
# 144069                      True                    False    1101000
# 146245                      True                    False    1101000
#
#         change_in_cvh
# 2871         0.137791
# 2903         0.115998
# 2933         0.117747
# 2967         0.113432
# 28804        0.193693
# 29071        0.247284
# 29347        0.127858
# 38575        0.280908
# 40926        0.308048
# 44100        0.114751
# 50056        0.191312
# 58230        0.130046
# 61993        0.150617
# 70703        0.228696
# 119619       0.112918
# 121360       0.260938
# 122298       0.104007
# 122806       0.100039
# 126718       0.102535
# 132110       0.195276
# 132112       0.300764
# 132533       0.105627
# 132535       0.181513
# 132536       0.100957
# 134448       0.112902
# 134914       0.105615
# 139025       0.122226
# 144068       0.102229
# 144069       0.104719
# 146245       0.143580
#
# [30 rows x 45 columns]
