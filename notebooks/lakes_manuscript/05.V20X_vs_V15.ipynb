# %% [markdown]
# # This notebook compares the V15 and V20X prediction errors for different bitstrings

# %% [markdown]
# #### Load the data

# %%
import pandas as pd
df = pd.read_pickle('tmp_data/clean_yearly_data.pkl')

# %% [markdown]
# #### Create a plotting function

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import cartopy.crs as ccrs
import matplotlib.colors as mc
import matplotlib.colorbar as cb 


def RobinsonPlot(df,z,vmin,vmax,cmap,markersize,savefig):


    #Setup plotting env
    fig = plt.figure(figsize=[30,20])
    ax = plt.subplot(projection=ccrs.Robinson(central_longitude=0))
    cax = fig.add_axes([0.32, 0.11, 0.4, 0.0125])

    #Get data
    x = df['latitude_ERA']
    y = df['longitude_ERA']
    z1 = df[z]
    
    
    #Normalise
    norm = mc.Normalize(vmin=vmin, vmax=vmax)

    #Colorbar
    cb1 = cb.ColorbarBase(cax, cmap=cmap,
                               norm=norm,
                               orientation='horizontal'
                               )
    #Scatter points
    sc = ax.scatter(y,x,transform=ccrs.PlateCarree(),
                    s=markersize,
                    c=cmap(norm(z1)),
                    linewidths=1, 
                    alpha=.7)


    #Latitude cutoffs
    ax.plot([-180,180],[70,70],transform=ccrs.PlateCarree(),c='0.5', linestyle='--')
    ax.plot([-180,180],[-70,-70],transform=ccrs.PlateCarree(),c='0.5', linestyle='--')


    
    #Formatting
    cax.tick_params(labelsize=30)
    cax.set_xlabel(r'$\delta$K',fontsize=34)
    

    ax.coastlines()
    ax.set_aspect('auto') #Force projection aspect ratio
    
    ax.scatter(180,0,c='1',transform=ccrs.PlateCarree(),s=100,alpha=0.1) #invisible point to set plot limits. Hacky, but works OK.
    #ax.scatter(180,0,c='k')

    #ax.set_xlim(-180,180)

    if savefig is not None:
        plt.savefig(savefig,bbox_inches='tight', pad_inches=0, dpi=300)

# %% [markdown]
# ## Bitstring 100110

# %%
df_1100110 = df.query('bitstring == "100110"')

# %% [markdown]
# #### Check out some of the worst points - these are mentioned in the manuscript

# %%
ivals = [0,1,2,3,4]  # #Gujarat, Salt lake city, Peru, Northern Algeria,Australia
i = 3
df_1100110.sort_values(by=['delta'],ascending=False).iloc[i]
# Out:
# latitude_ERA                        34.145187
# longitude_ERA                            6.08
# MODIS_LST                          309.881317
# V15_prediction                     311.362732
# V20_prediction                     316.291443
# V20X_prediction                    310.715393
# V15_error                            3.900536
# V20_error                             6.43271
# V20X_error                           4.158387
# delta                                2.532175
# deltaX                               0.257852
# values                                 120116
# step                          0 days 00:00:00
# surface                                   0.0
# latitude                            34.145187
# longitude                                6.08
# change_in_cl                        -0.332759
# V15_cl                               0.332777
# V20_cl                               0.000018
# percentage_change_in_cl             -0.999947
# heightAboveGround                        10.0
# change_in_si10                            0.0
# V15_si10                                  0.0
# V20_si10                                  0.0
# percentage_change_in_si10                 NaN
# change_in_cvh                             0.0
# V15_cvh                               0.00174
# V20_cvh                               0.00174
# percentage_change_in_cvh                  0.0
# change_in_cvl                         0.00001
# V15_cvl                              0.021902
# V20_cvl                              0.021912
# percentage_change_in_cvl             0.000452
# change_in_lsm                        0.332759
# V15_lsm                              0.667223
# V20_lsm                              0.999982
# percentage_change_in_lsm             0.498723
# change_in_dl                        -19.77832
# V15_dl                               20.77832
# V20_dl                                    1.0
# percentage_change_in_dl             -0.951873
# cl_change_is_significant                 True
# si10_change_is_significant              False
# cvh_change_is_significant               False
# cvl_change_is_significant               False
# lsm_change_is_significant                True
# dl_change_is_significant                 True
# bitstring                              100110
# Name: 89090, dtype: object

# %% [markdown]
# #### Which points saw the greatest improvement in delta?

# %%
df_1100110['delta_change'] = df_1100110['deltaX'] - df_1100110['delta']
# Out:
# /home/k/kimpson/bin/conda/envs/workhorse/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_1100110.sort_values(by=['delta_change'],ascending=True)#.iloc[i]
# Out:
#         latitude_ERA  longitude_ERA   MODIS_LST  V15_prediction  \
# 86756      32.740036       43.52000  311.081909      301.419189
# 84331      31.334884       47.68000  301.999573      316.069397
# 56016      13.348942       14.34375  306.201447      316.980011
# 149660     70.117048      -24.00000  258.501343      265.115753
# 101086     41.170945     -113.40000  294.736176      294.245392
# ...              ...            ...         ...             ...
# 63546      18.969549       32.06250  316.277527      320.372620
# 55695      13.067912       14.34375  300.874603      304.265411
# 33374      -6.323183      -80.71875  311.564301      308.391449
# 7807      -31.053854      139.84000  312.795837      311.083374
# 33375      -6.323183      -80.43750  314.165771      311.336700
#
#         V20_prediction  V20X_prediction  V15_error  V20_error  V20X_error  \
# 86756       303.957611       307.525848   9.741612   7.397593    4.090796
# 84331       312.127869       308.212158  14.092155  10.296273    7.264714
# 56016       316.964905       314.346619  10.798612  10.768510    8.209530
# 149660      265.274750       261.810822   7.608796   7.365232    4.990395
# 101086      302.931915       299.788849   3.573472   8.450400    6.104148
# ...                ...              ...        ...        ...         ...
# 63546       317.470917       311.540253   4.357863   2.710044    5.682619
# 55695       302.596771       306.583191   3.554063   2.387391    5.731228
# 33374       304.894409       300.358093   4.953901   7.726332   11.876699
# 7807        313.424377       320.634888   3.297467   3.304563    7.871571
# 33375       312.596832       305.696655   4.109239   3.509645    8.932360
#
#            delta  ...      V20_dl  percentage_change_in_dl  \
# 86756  -2.344019  ...   18.000000                -0.550000
# 84331  -3.795882  ...    6.725586                 2.394283
# 56016  -0.030102  ...    5.000000                 0.250000
# 149660 -0.243564  ...  123.036133                -0.694928
# 101086  4.876928  ...   27.000000                 8.000000
# ...          ...  ...         ...                      ...
# 63546  -1.647819  ...    3.000000                -0.880000
# 55695  -1.166672  ...    5.000000                 0.250000
# 33374   2.772430  ...   30.428711                 1.354288
# 7807    0.007096  ...    1.000000                -0.819813
# 33375  -0.599594  ...   14.855469                -0.405781
#
#        cl_change_is_significant  si10_change_is_significant  \
# 86756                      True                       False
# 84331                      True                       False
# 56016                      True                       False
# 149660                     True                       False
# 101086                     True                       False
# ...                         ...                         ...
# 63546                      True                       False
# 55695                      True                       False
# 33374                      True                       False
# 7807                       True                       False
# 33375                      True                       False
#
#         cvh_change_is_significant  cvl_change_is_significant  \
# 86756                       False                      False
# 84331                       False                      False
# 56016                       False                      False
# 149660                      False                      False
# 101086                      False                      False
# ...                           ...                        ...
# 63546                       False                      False
# 55695                       False                      False
# 33374                       False                      False
# 7807                        False                      False
# 33375                       False                      False
#
#         lsm_change_is_significant  dl_change_is_significant  bitstring  \
# 86756                        True                      True     100110
# 84331                        True                      True     100110
# 56016                        True                      True     100110
# 149660                       True                      True     100110
# 101086                       True                      True     100110
# ...                           ...                       ...        ...
# 63546                        True                      True     100110
# 55695                        True                      True     100110
# 33374                        True                      True     100110
# 7807                         True                      True     100110
# 33375                        True                      True     100110
#
#         delta_change
# 86756      -3.306798
# 84331      -3.031559
# 56016      -2.558980
# 149660     -2.374837
# 101086     -2.346252
# ...              ...
# 63546       2.972575
# 55695       3.343837
# 33374       4.150368
# 7807        4.567008
# 33375       5.422715
#
# [1512 rows x 49 columns]

# %%
RobinsonPlot(df_1100110,'delta_change',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 100,savefig=None)

# %% [markdown]
# #### Isolate northern canada and lena river

# %%
northern_canada = df_1100110.query('-141 < longitude_ERA < -92 & 60 < latitude_ERA < 70')
lena_river = df_1100110.query('119 < longitude_ERA < 136 & 62 < latitude_ERA < 74')

#RobinsonPlot(northern_canada,'delta_change',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 100,savefig=None)
#RobinsonPlot(lena_river,'delta_change',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 100,savefig=None)

high_latitutde_regions = pd.concat([northern_canada,lena_river])

# %%
high_latitutde_regions.delta.mean()
# Out:
# 0.02660809

# %%
high_latitutde_regions.deltaX.mean()
# Out:
# -0.0778467

# %% [markdown]
# ## Bitstring 000101

# %%
df_000101 = df.query('bitstring == "000101"')

# %%
RobinsonPlot(df_000101,'deltaX',vmin=-2,vmax=+2,cmap=plt.cm.coolwarm,markersize = 20,savefig=None)

# %%
#Alaskan gulf point
df_000101.sort_values(by=['delta'],ascending=False).iloc[0]
# Out:
# latitude_ERA                         59.99997
# longitude_ERA                     -141.866667
# MODIS_LST                          271.977448
# V15_prediction                     277.694244
# V20_prediction                     261.428802
# V20X_prediction                    275.110748
# V15_error                            6.214495
# V20_error                           10.868941
# V20X_error                           4.763571
# delta                                4.654447
# deltaX                              -1.450924
# values                                  37428
# step                          0 days 00:00:00
# surface                                   0.0
# latitude                             59.99997
# longitude                         -141.866667
# change_in_cl                          0.00121
# V15_cl                                    0.0
# V20_cl                                0.00121
# percentage_change_in_cl                   inf
# heightAboveGround                        10.0
# change_in_si10                       0.112061
# V15_si10                             0.164856
# V20_si10                             0.276917
# percentage_change_in_si10            0.679748
# change_in_cvh                             0.0
# V15_cvh                                   0.0
# V20_cvh                                   0.0
# percentage_change_in_cvh                  NaN
# change_in_cvl                             0.0
# V15_cvl                                   0.0
# V20_cvl                                   0.0
# percentage_change_in_cvl                  NaN
# change_in_lsm                         0.08266
# V15_lsm                              0.438392
# V20_lsm                              0.521052
# percentage_change_in_lsm             0.188552
# change_in_dl                        69.787109
# V15_dl                              38.737305
# V20_dl                             108.524414
# percentage_change_in_dl              1.801548
# cl_change_is_significant                False
# si10_change_is_significant               True
# cvh_change_is_significant               False
# cvl_change_is_significant               False
# lsm_change_is_significant               False
# dl_change_is_significant                 True
# bitstring                              000101
# Name: 133962, dtype: object

# %% [markdown]
# ## Bitstring 010100

# %%
df_010100 = df.query('bitstring == "010100"')

# %%
df_010100.sort_values(by=['delta'],ascending=False).iloc[4]
# Out:
# latitude_ERA                        -0.983606
# longitude_ERA                        98.71875
# MODIS_LST                          299.748657
# V15_prediction                     299.439484
# V20_prediction                     311.325012
# V20X_prediction                    300.483948
# V15_error                            2.597664
# V20_error                           11.576346
# V20X_error                           2.598799
# delta                                8.978683
# deltaX                               0.001135
# values                                 275231
# step                          0 days 00:00:00
# surface                                   0.0
# latitude                            -0.983606
# longitude                            98.71875
# change_in_cl                         0.000036
# V15_cl                                    0.0
# V20_cl                               0.000036
# percentage_change_in_cl                   inf
# heightAboveGround                        10.0
# change_in_si10                            0.0
# V15_si10                                  0.0
# V20_si10                                  0.0
# percentage_change_in_si10                 NaN
# change_in_cvh                       -0.521362
# V15_cvh                              0.521362
# V20_cvh                                   0.0
# percentage_change_in_cvh                 -1.0
# change_in_cvl                             0.0
# V15_cvl                                   0.0
# V20_cvl                                   0.0
# percentage_change_in_cvl                  NaN
# change_in_lsm                       -0.035765
# V15_lsm                               0.52491
# V20_lsm                              0.489145
# percentage_change_in_lsm            -0.068136
# change_in_dl                       103.749023
# V15_dl                                   25.0
# V20_dl                             128.749023
# percentage_change_in_dl              4.149961
# cl_change_is_significant                False
# si10_change_is_significant              False
# cvh_change_is_significant                True
# cvl_change_is_significant               False
# lsm_change_is_significant               False
# dl_change_is_significant                 True
# bitstring                              010100
# Name: 40088, dtype: object

# %%
df_010100[['latitude_ERA', 'longitude_ERA', 'V15_cl', 'V15_cvh', 'V20_cvh']]
# Out:
#         latitude_ERA  longitude_ERA    V15_cl   V15_cvh  V20_cvh
# 4389      -37.798581     148.666667  0.000000  0.612854      0.0
# 38577      -2.107728     -54.000000  0.473621  0.533661      0.0
# 40088      -0.983606      98.718750  0.000000  0.521362      0.0
# 40808      -0.421546     132.187500  0.000000  0.493011      0.0
# 40928      -0.140515     -50.062500  0.000000  0.596222      0.0
# 44374       2.950819     112.218750  0.000000  0.591125      0.0
# 54271      11.662760     102.937500  0.000000  0.413391      0.0
# 69458      22.903974     -83.400000  0.000000  0.561340      0.0
# 86246      32.459005      34.880000  0.000000  0.413116      0.0
# 89842      34.426218     131.333333  0.000000  0.446869      0.0
# 105121     43.419187      -4.125000  0.000000  0.668671      0.0
# 135369     60.843060    -115.555556  0.462168  0.605804      0.0
# 141003     64.215421      23.750000  0.000000  0.570129      0.0

# %%
df_010100.iloc[1].latitude
# Out:
# -2.10772769472398
