# %%
import json
import numpy as np 
import matplotlib.pyplot as plt 
def plot_training_history(path,logscale,jump_n_epochs,upper_limit,lower_limit):
    
    print('Path =', path)
    
#     with open(path+'meta.txt') as f:
#         lines = f.readlines()
#         print(*lines)
#         #print( [row for row in lines])
    
    
    
    
    with open(path+'/training_history.json') as f:
        d = json.load(f)
        i = jump_n_epochs
        training_loss = d['loss'][i:]
        epochs = np.arange(len(training_loss))
        
        
        idxmin = np.argmin(training_loss)
        

        fig = plt.figure(figsize=(10, 10))
        plt.plot(epochs,training_loss,label='training loss')
        plt.scatter(epochs[idxmin],training_loss[idxmin])

        try:
            validation_loss = d['val_loss'][i:]
            idxmin = np.argmin(validation_loss)
            plt.plot(epochs,validation_loss, label='validation loss')
            plt.scatter(epochs[idxmin],validation_loss[idxmin])
            print('Minimum validation loss:',validation_loss[idxmin])

        except:
            pass
        plt.legend()
        
        if logscale:
            plt.yscale('log')
            
            
        plt.ylim(lower_limit,upper_limit)
        print('----------------------------------------------')

# %%
import glob 

root = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/processed_data/trained_models/'
file_id = "V15"
    
models = sorted(glob.glob(f'{root}{file_id}_noise_expt_*'))
    
    
    
for path in models: 
    
    plot_training_history(path,False,jump_n_epochs=1,upper_limit=None,lower_limit=None)
# Out:
# Path = /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/processed_data/trained_models/V15_noise_expt_1
# Minimum validation loss: 16.185543060302734
# ----------------------------------------------
# Path = /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/processed_data/trained_models/V15_noise_expt_2
# Minimum validation loss: 16.229642868041992
# ----------------------------------------------
# Path = /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/processed_data/trained_models/V15_noise_expt_3
# Minimum validation loss: 16.51604461669922
# ----------------------------------------------
# Path = /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/processed_data/trained_models/V15_noise_expt_4
# Minimum validation loss: 16.100568771362305
# ----------------------------------------------

# %%
import glob 

root = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/processed_data/trained_models/'
file_id = "V20"
    
models = sorted(glob.glob(f'{root}{file_id}_noise_expt_*'))
    
    
    
for path in models: 
    
    plot_training_history(path,False,jump_n_epochs=1,upper_limit=None,lower_limit=None)
# Out:
# Path = /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/processed_data/trained_models/V20_noise_expt_1
# Minimum validation loss: 15.49809455871582
# ----------------------------------------------
# Path = /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/processed_data/trained_models/V20_noise_expt_2
# Minimum validation loss: 15.38018798828125
# ----------------------------------------------
# Path = /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/processed_data/trained_models/V20_noise_expt_3
# Minimum validation loss: 15.552045822143555
# ----------------------------------------------
# Path = /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/processed_data/trained_models/V20_noise_expt_4
# Minimum validation loss: 15.646662712097168
# ----------------------------------------------
