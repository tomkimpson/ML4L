# %% [markdown]
# ### Noise calculations for paper revisions
#
#
# This notebook explores the model training noise as requested during the first round of paper review.
#
# We use the conda environment `analysis`

# %% [markdown]
# #### Define paths to model files

# %%
root = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/processed_data/trained_models/'
model_1 = f'{root}V15_noise_expt_1/'
model_2 = f'{root}V15_noise_expt_2/'
model_3 = f'{root}V15_noise_expt_3/'
model_4 = f'{root}V15_noise_expt_4/'

# %% [markdown]
# #### Define some useful functions

# %%
import pandas as pd
def load_predictions(path):

    df = pd.read_parquet(path+'predictions.parquet')
    
    
    #Calculate some extra columns
    df['model_predicion_bias'] = df.MODIS_LST - df.predictions
    df['model_predicion_error'] = abs(df.MODIS_LST - df.predictions)
        
    df['ERA_predicion_bias'] = df.MODIS_LST - df.skt_unnormalised
    df['ERA_predicion_error'] = abs(df.MODIS_LST - df.skt_unnormalised)


    print ('----------------------------------MODEL-------------------------------------------------')
    print("Mean/Median/Std prediction bias:", df['model_predicion_bias'].mean(), df['model_predicion_bias'].median(),df['model_predicion_bias'].std())
    print("Mean/Median/Std prediction error:", df['model_predicion_error'].mean(), df['model_predicion_error'].median(),df['model_predicion_error'].std())
    # print ('------------------------------------ERA---------------------------------------------------')
    # print("Mean/Median/Std prediction bias:", df['ERA_predicion_bias'].mean(), df['ERA_predicion_bias'].median(),df['ERA_predicion_bias'].std())
    # print("Mean/Median/Std prediction error:", df['ERA_predicion_error'].mean(), df['ERA_predicion_error'].median(),df['ERA_predicion_error'].std())
    # print ('-------------------------------------------------------------------------------------------')

    
    
    #Average predictions and errors over the year
    df_grouped = df.groupby(['latitude_ERA', 'longitude_ERA'],as_index=False).mean() 
    
    
    
    
    
    return df,df_grouped

import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import cartopy.crs as ccrs
import matplotlib.colors as mc
import matplotlib.colorbar as cb 




        
        
        
def global_plot(df,z,projection,vmin,vmax,cmap,absolute_values,logscale,title,markersize,savefig):
    
    
        
       # ccrs.Robinson()
        
    #Setup plotting env
    fig = plt.figure(figsize=[30,20])
    ax = plt.subplot(projection=projection)
    cax = fig.add_axes([0.32, 0.11, 0.4, 0.0125])

    #Get data
    try:
        x = df.longitude
        y = df.latitude
    except: #different sources call lat/lon different things
        x = df.longitude_ERA
        y = df.latitude_ERA

    z1 = df[z]
    if absolute_values:
        z1 = abs(z1)
        if vmin < 0:
            vmin = 0 # dont need negative vmins if plotting absolute values
    
    
    #Normalize, colorbars
    if vmin is None:
        vmin = min(z1)
    if vmax is None:
        vmax = max(z1)
        

     #Cmaps, normalisations
    if logscale:
        norm = mc.LogNorm(vmin=vmin, vmax=vmax)
        z1 = abs(z1)
    else:
        norm = mc.Normalize(vmin=vmin, vmax=vmax)

    
    cb1 = cb.ColorbarBase(cax, cmap=cmap,
                                norm=norm,
                                orientation='horizontal')
    
    
    
    
    
    
    #Scatter points
    sc = ax.scatter(x,y,transform=ccrs.PlateCarree(), #Always PlateCarree
                    s=markersize,
                    c=cmap(norm(z1)),
                    linewidths=1, 
                    alpha=.7)


    #Latitude cutoffs
    ax.plot([-180,180],[70,70],transform=ccrs.PlateCarree(),c='0.5', linestyle='--')
    ax.plot([-180,180],[-70,-70],transform=ccrs.PlateCarree(),c='0.5', linestyle='--')


    #Formatting
    cax.tick_params(labelsize=30)
    cax.set_xlabel(r'$\delta$K',fontsize=34)

    ax.set_title(title)    
    ax.coastlines()
    ax.set_aspect('auto') #Force projection aspect ratio
    #ax.set_xlim(-180,180)

    if savefig is not None:
        plt.savefig(savefig,bbox_inches='tight', pad_inches=0, dpi=300)

# %%
models_to_compare = [model_1,model_2, model_3,model_4]


annually_averaged_dfs = []
for m in models_to_compare:
    predictions,predictions_averaged = load_predictions(m)
    annually_averaged_dfs.extend([predictions_averaged])
# Out:
# ----------------------------------MODEL-------------------------------------------------
# Mean/Median/Std prediction bias: 0.08259364 0.226959228515625 3.8190529346466064
# Mean/Median/Std prediction error: 2.9854784 2.280975341796875 2.499044418334961
# <ipython-input-28-019f89ba43d9>:26: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped = df.groupby(['latitude_ERA', 'longitude_ERA'],as_index=False).mean()
# ----------------------------------MODEL-------------------------------------------------
# Mean/Median/Std prediction bias: 0.17329945 0.29364013671875 3.8254127502441406
# Mean/Median/Std prediction error: 2.9893332 2.27545166015625 2.509122133255005
# <ipython-input-28-019f89ba43d9>:26: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped = df.groupby(['latitude_ERA', 'longitude_ERA'],as_index=False).mean()
# ----------------------------------MODEL-------------------------------------------------
# Mean/Median/Std prediction bias: 0.0777295 0.20306396484375 3.8673462867736816
# Mean/Median/Std prediction error: 3.0292234 2.315216064453125 2.526977300643921
# <ipython-input-28-019f89ba43d9>:26: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped = df.groupby(['latitude_ERA', 'longitude_ERA'],as_index=False).mean()
# ----------------------------------MODEL-------------------------------------------------
# Mean/Median/Std prediction bias: 0.06500694 0.195526123046875 3.8166935443878174
# Mean/Median/Std prediction error: 2.9783933 2.266021728515625 2.5020196437835693
# <ipython-input-28-019f89ba43d9>:26: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped = df.groupby(['latitude_ERA', 'longitude_ERA'],as_index=False).mean()

# %% [markdown]
# #### Load the change in fields file - we will use this to categorise gridpoints

# %%
change_in_fields = pd.read_pickle('tmp_data/change_in_fields.pkl')
change_in_fields['latitude_join'] = round(change_in_fields.latitude_ERA,3)
change_in_fields['longitude_join'] = round(change_in_fields.longitude_ERA,3) #just used for joining due to loss of precision from Margs file

# %%
change_in_fields.columns
# Out:
# Index(['latitude_ERA', 'longitude_ERA', 'V15_clFr', 'V15_cvhFr', 'V15_cvlFr',
#        'V15_dl', 'V15_oceanFr', 'V15_si10Fr', 'V15_z', 'V20_clFr', 'V20_cvhFr',
#        'V20_cvlFr', 'V20_dl', 'V20_oceanFr', 'V20_si10Fr', 'V20_z',
#        'changeAbs_V20V15_clFr', 'changeAbs_V20V15_cvhFr',
#        'changeAbs_V20V15_cvlFr', 'changeAbs_V20V15_oceanFr',
#        'changeAbs_V20V15_si10Fr', 'changeAbs_V20V15_dl', 'changeAbs_V20V15_z',
#        'clFr_change_is_significant', 'cvhFr_change_is_significant',
#        'cvlFr_change_is_significant', 'oceanFr_change_is_significant',
#        'si10Fr_change_is_significant', 'dl_change_is_significant',
#        'z_change_is_significant', 'bitstring', 'latitude_join',
#        'longitude_join'],
#       dtype='object')

# %% [markdown]
# #### Create a new df and concat it with the change in fields df

# %%
#Create a new df that will just hold the differences   

df =annually_averaged_dfs[0] #pick a df to get latitudes 
data = { 'latitude_ERA':     df.latitude_ERA, 
         'longitude_ERA':    df.longitude_ERA,
         'MODIS_LST':        df.MODIS_LST,
          'latitude_join':    round(df.latitude_ERA,3), 
          'longitude_join':    round(df.longitude_ERA,3)}


i = 1
selected_cols = [] #we will use this later when computing variances
for df in annually_averaged_dfs:
    data[f'prediction_error_{i}'] = df['model_predicion_error']
    data[f'prediction_{i}'] = df['predictions']

    selected_cols.extend([f'prediction_error_{i}'])
    i = i+1

df_new = pd.DataFrame(data)

# %%
df_c = pd.concat(annually_averaged_dfs,ignore_index=True)
df_c["latitude_join"] = round(df_c.latitude_ERA,3)
df_c["longitude_join"] = round(df_c.longitude_ERA,3)

# %%
df_fields = pd.concat([change_in_fields,change_in_fields,change_in_fields,change_in_fields],ignore_index=True)

# %%
df_fields
# Out:
#         latitude_ERA  longitude_ERA  V15_clFr  V15_cvhFr  V15_cvlFr  \
# 0         -54.941427      -66.56250  0.147125   0.007210   0.731774
# 1         -54.660397      -70.31250  0.182325   0.193664   0.301594
# 2         -54.660397      -69.84375  0.092898   0.067518   0.178301
# 3         -54.660397      -69.37500  0.136888   0.053549   0.190927
# 4         -54.660397      -68.90625  0.039358   0.159833   0.631237
# ...              ...            ...       ...        ...        ...
# 599235     64.496451      169.37500  0.000000   0.000000   1.000000
# 599236     65.058510       95.00000  0.000000   0.000000   1.000000
# 599237     65.620570       98.12500  0.000000   0.000000   1.000000
# 599238     69.554988     -159.00000  0.000000   0.000000   1.000000
# 599239     69.554988      105.75000  0.000000   0.000000   1.000000
#
#             V15_dl  V15_oceanFr  V15_si10Fr        V15_z  V20_clFr  ...  \
# 0         5.005859          0.0    0.000000  1952.714722  0.004767  ...
# 1         6.428711          0.0    0.250059  5086.468750  0.048344  ...
# 2         6.771484          0.0    0.637169  7635.152344  0.011764  ...
# 3       100.000000          0.0    0.514738  7530.796875  0.003248  ...
# 4       100.000000          0.0    0.137348  6271.117188  0.011331  ...
# ...            ...          ...         ...          ...       ...  ...
# 599235   25.000000          0.0    0.000000  2940.859375  0.000030  ...
# 599236   25.000000          0.0    0.000000  5395.695312  0.000030  ...
# 599237   25.000000          0.0    0.000000  5872.917969  0.000030  ...
# 599238   25.000000          0.0    0.000000  1342.546753  0.000030  ...
# 599239   25.000000          0.0    0.000000  6222.046875  0.000030  ...
#
#         clFr_change_is_significant  cvhFr_change_is_significant  \
# 0                             True                        False
# 1                             True                         True
# 2                            False                        False
# 3                             True                        False
# 4                            False                        False
# ...                            ...                          ...
# 599235                       False                        False
# 599236                       False                        False
# 599237                       False                        False
# 599238                       False                        False
# 599239                       False                        False
#
#         cvlFr_change_is_significant  oceanFr_change_is_significant  \
# 0                             False                           True
# 1                              True                          False
# 2                              True                          False
# 3                              True                          False
# 4                              True                          False
# ...                             ...                            ...
# 599235                        False                          False
# 599236                        False                          False
# 599237                        False                          False
# 599238                        False                          False
# 599239                        False                          False
#
#         si10Fr_change_is_significant  dl_change_is_significant  \
# 0                              False                      True
# 1                               True                      True
# 2                               True                      True
# 3                               True                      True
# 4                               True                      True
# ...                              ...                       ...
# 599235                         False                      True
# 599236                         False                      True
# 599237                         False                      True
# 599238                         False                      True
# 599239                         False                      True
#
#         z_change_is_significant  bitstring  latitude_join  longitude_join
# 0                         False    1001100        -54.941         -66.562
# 1                         False    1111010        -54.660         -70.312
# 2                          True    0011011        -54.660         -69.844
# 3                          True    1011011        -54.660         -69.375
# 4                         False    0011010        -54.660         -68.906
# ...                         ...        ...            ...             ...
# 599235                    False    0001000         64.496         169.375
# 599236                    False    0001000         65.059          95.000
# 599237                    False    0001000         65.621          98.125
# 599238                    False    0001000         69.555        -159.000
# 599239                    False    0001000         69.555         105.750
#
# [599240 rows x 33 columns]

# %%
df_c
# Out:
#         latitude_ERA  longitude_ERA   MODIS_LST  skt_unnormalised  \
# 0         -70.117048         -75.75  256.971741        267.617157
# 1         -70.117048         -75.00  256.868408        265.903412
# 2         -70.117048         -72.00  255.929321        262.387939
# 3         -70.117048         -71.25  254.781509        262.062439
# 4         -70.117048         -70.50  255.270554        263.084961
# ...              ...            ...         ...               ...
# 599243     70.117048         168.00  264.279388        264.639862
# 599244     70.117048         168.75  263.243958        264.017853
# 599245     70.117048         170.25  266.316162        263.479065
# 599246     70.117048         171.00  266.383087        264.144928
# 599247     70.117048         171.75  264.890991        264.248352
#
#         number_of_modis_observations  predictions  model_predicion_bias  \
# 0                           9.592965   261.956726             -4.984949
# 1                           8.472906   258.348328             -1.479933
# 2                           5.629213   256.975433             -1.046120
# 3                          16.563380   257.899200             -3.117676
# 4                          15.144860   258.368469             -3.097925
# ...                              ...          ...                   ...
# 599243                      7.555556   264.561401             -0.282000
# 599244                     10.601562   264.265045             -1.021091
# 599245                      2.850622   262.855042              3.461125
# 599246                     17.839286   264.134155              2.248947
# 599247                     14.062044   263.914856              0.976127
#
#         model_predicion_error  ERA_predicion_bias  ERA_predicion_error  \
# 0                    5.739560          -10.645395            10.645395
# 1                    4.801536           -9.035011             9.152896
# 2                    5.909410           -6.458648             7.239628
# 3                    5.630957           -7.280914             7.748164
# 4                    6.004992           -7.814422             8.111403
# ...                       ...                 ...                  ...
# 599243               3.557045           -0.360485             6.803514
# 599244               3.692894           -0.773880             6.388465
# 599245               5.607152            2.837097             7.430747
# 599246               4.934265            2.238165             7.608860
# 599247               3.837795            0.642652             6.673814
#
#         latitude_join  longitude_join
# 0             -70.117          -75.75
# 1             -70.117          -75.00
# 2             -70.117          -72.00
# 3             -70.117          -71.25
# 4             -70.117          -70.50
# ...               ...             ...
# 599243         70.117          168.00
# 599244         70.117          168.75
# 599245         70.117          170.25
# 599246         70.117          171.00
# 599247         70.117          171.75
#
# [599248 rows x 12 columns]

# %%
#Join and save
df_cat = pd.merge(df_c,change_in_fields,how='inner',on=['latitude_join', 'longitude_join'],suffixes=('', '_y')) #inner join.
df_cat = df_cat.drop(['latitude_join', 'longitude_join','latitude_ERA_y', 'longitude_ERA_y'], axis=1) #Get rid of junk columns

# %%
df_cat
# Out:
#         latitude_ERA  longitude_ERA   MODIS_LST  skt_unnormalised  \
# 0         -70.117048         -75.75  256.971741        267.617157
# 1         -70.117048         -75.75  256.971741        267.617157
# 2         -70.117048         -75.75  256.971741        267.617157
# 3         -70.117048         -75.75  256.971741        267.617157
# 4         -70.117048         -75.00  256.868408        265.903412
# ...              ...            ...         ...               ...
# 599167     70.117048         171.00  266.383087        264.144928
# 599168     70.117048         171.75  264.890991        264.248352
# 599169     70.117048         171.75  264.890991        264.248352
# 599170     70.117048         171.75  264.890991        264.248352
# 599171     70.117048         171.75  264.890991        264.248352
#
#         number_of_modis_observations  predictions  model_predicion_bias  \
# 0                           9.592965   261.956726             -4.984949
# 1                           9.592965   260.129364             -3.157624
# 2                           9.592965   259.914642             -2.942888
# 3                           9.592965   262.060181             -5.088417
# 4                           8.472906   258.348328             -1.479933
# ...                              ...          ...                   ...
# 599167                     17.839286   264.134155              2.248947
# 599168                     14.062044   263.181000              1.710002
# 599169                     14.062044   263.327301              1.563703
# 599170                     14.062044   262.376068              2.514932
# 599171                     14.062044   263.914856              0.976127
#
#         model_predicion_error  ERA_predicion_bias  ERA_predicion_error  ...  \
# 0                    5.739560          -10.645395            10.645395  ...
# 1                    5.066422          -10.645395            10.645395  ...
# 2                    4.930738          -10.645395            10.645395  ...
# 3                    5.782263          -10.645395            10.645395  ...
# 4                    4.801536           -9.035011             9.152896  ...
# ...                       ...                 ...                  ...  ...
# 599167               4.934265            2.238165             7.608860  ...
# 599168               4.176829            0.642652             6.673814  ...
# 599169               4.126025            0.642652             6.673814  ...
# 599170               4.395240            0.642652             6.673814  ...
# 599171               3.837795            0.642652             6.673814  ...
#
#         changeAbs_V20V15_dl  changeAbs_V20V15_z  clFr_change_is_significant  \
# 0                154.697266           17.205444                       False
# 1                154.697266           17.205444                       False
# 2                154.697266           17.205444                       False
# 3                154.697266           17.205444                       False
# 4                 80.971680            6.377319                       False
# ...                     ...                 ...                         ...
# 599167             0.864258            1.685913                       False
# 599168             0.235352            1.084351                       False
# 599169             0.235352            1.084351                       False
# 599170             0.235352            1.084351                       False
# 599171             0.235352            1.084351                       False
#
#         cvhFr_change_is_significant  cvlFr_change_is_significant  \
# 0                             False                        False
# 1                             False                        False
# 2                             False                        False
# 3                             False                        False
# 4                             False                        False
# ...                             ...                          ...
# 599167                        False                        False
# 599168                        False                        False
# 599169                        False                        False
# 599170                        False                        False
# 599171                        False                        False
#
#         oceanFr_change_is_significant  si10Fr_change_is_significant  \
# 0                                True                          True
# 1                                True                          True
# 2                                True                          True
# 3                                True                          True
# 4                               False                          True
# ...                               ...                           ...
# 599167                          False                         False
# 599168                          False                         False
# 599169                          False                         False
# 599170                          False                         False
# 599171                          False                         False
#
#         dl_change_is_significant  z_change_is_significant  bitstring
# 0                           True                     True    0001111
# 1                           True                     True    0001111
# 2                           True                     True    0001111
# 3                           True                     True    0001111
# 4                           True                    False    0001010
# ...                          ...                      ...        ...
# 599167                     False                    False    0000000
# 599168                     False                    False    0000000
# 599169                     False                    False    0000000
# 599170                     False                    False    0000000
# 599171                     False                    False    0000000
#
# [599172 rows x 39 columns]

# %% [markdown]
# df_lake = df_cat.query('clFr_change_is_significant & dl_change_is_significant & not oceanFr_change_is_significant & not si10Fr_change_is_significant')
# #### LAKES

# %%
df_lake = df_cat.query('clFr_change_is_significant & dl_change_is_significant & not oceanFr_change_is_significant & not si10Fr_change_is_significant')

# %%
df_lake
# Out:
#         latitude_ERA  longitude_ERA   MODIS_LST  skt_unnormalised  \
# 9192      -54.379367      -68.90625  278.404236        278.819580
# 9193      -54.379367      -68.90625  278.404236        278.819580
# 9194      -54.379367      -68.90625  278.404236        278.819580
# 9195      -54.379367      -68.90625  278.404236        278.819580
# 10096     -51.007004      -73.75000  274.123169        277.435883
# ...              ...            ...         ...               ...
# 599123     70.117048      154.50000  260.750122        264.749054
# 599148     70.117048      159.75000  260.544830        264.479279
# 599149     70.117048      159.75000  260.544830        264.479279
# 599150     70.117048      159.75000  260.544830        264.479279
# 599151     70.117048      159.75000  260.544830        264.479279
#
#         number_of_modis_observations  predictions  model_predicion_bias  \
# 9192                       38.665236   276.383575              2.020678
# 9193                       38.665236   277.031494              1.372742
# 9194                       38.665236   277.640930              0.763314
# 9195                       38.665236   277.906799              0.497455
# 10096                      28.529801   275.111725             -0.988563
# ...                              ...          ...                   ...
# 599123                     18.826855   262.437927             -1.687782
# 599148                     13.459144   260.735657             -0.190804
# 599149                     13.459144   261.164459             -0.619604
# 599150                     13.459144   260.808319             -0.263458
# 599151                     13.459144   261.291962             -0.747095
#
#         model_predicion_error  ERA_predicion_bias  ERA_predicion_error  ...  \
# 9192                 2.932979           -0.415330             2.465332  ...
# 9193                 2.512748           -0.415330             2.465332  ...
# 9194                 2.310007           -0.415330             2.465332  ...
# 9195                 2.243198           -0.415330             2.465332  ...
# 10096                4.816545           -3.312713             5.405634  ...
# ...                       ...                 ...                  ...  ...
# 599123               3.153682           -3.998951             4.797287  ...
# 599148               3.031477           -3.934412             4.642508  ...
# 599149               3.260163           -3.934412             4.642508  ...
# 599150               3.252664           -3.934412             4.642508  ...
# 599151               3.227924           -3.934412             4.642508  ...
#
#         changeAbs_V20V15_dl  changeAbs_V20V15_z  clFr_change_is_significant  \
# 9192              70.980469            5.107422                        True
# 9193              70.980469            5.107422                        True
# 9194              70.980469            5.107422                        True
# 9195              70.980469            5.107422                        True
# 10096            134.625977           26.759766                        True
# ...                     ...                 ...                         ...
# 599123             7.102539            0.103882                        True
# 599148            18.551758            2.403931                        True
# 599149            18.551758            2.403931                        True
# 599150            18.551758            2.403931                        True
# 599151            18.551758            2.403931                        True
#
#         cvhFr_change_is_significant  cvlFr_change_is_significant  \
# 9192                          False                        False
# 9193                          False                        False
# 9194                          False                        False
# 9195                          False                        False
# 10096                         False                        False
# ...                             ...                          ...
# 599123                        False                         True
# 599148                        False                        False
# 599149                        False                        False
# 599150                        False                        False
# 599151                        False                        False
#
#         oceanFr_change_is_significant  si10Fr_change_is_significant  \
# 9192                            False                         False
# 9193                            False                         False
# 9194                            False                         False
# 9195                            False                         False
# 10096                           False                         False
# ...                               ...                           ...
# 599123                          False                         False
# 599148                          False                         False
# 599149                          False                         False
# 599150                          False                         False
# 599151                          False                         False
#
#         dl_change_is_significant  z_change_is_significant  bitstring
# 9192                        True                    False    1001000
# 9193                        True                    False    1001000
# 9194                        True                    False    1001000
# 9195                        True                    False    1001000
# 10096                       True                    False    1001000
# ...                          ...                      ...        ...
# 599123                      True                    False    1011000
# 599148                      True                     True    1001001
# 599149                      True                     True    1001001
# 599150                      True                     True    1001001
# 599151                      True                     True    1001001
#
# [6524 rows x 39 columns]

# %%
df_lake['model_predicion_error'].hist(bins=100,figsize=(12,8))
# Out:
# <Axes: >

# %%
lake_natron = df_lake.query('latitude_ERA == -2.3887580539270044 & longitude_ERA == 36.0000')

# %%
lake_natron['model_predicion_error'].hist(figsize=(12,8))
# Out:
# <Axes: >

# %%
pd.options.mode.chained_assignment = None #Ignore SettingWithCopyWarning - we are safe here


def surface_noise_numbers(df):
    df['variance']=df[selected_cols].var(axis=1) #variance over the prediciton errors i.e. noise 
    df['median_error']=df[selected_cols].median(axis=1) #mean over the prediciton errors 
    df['mean_error']=df[selected_cols].mean(axis=1) #mean over the prediciton errors 
    
    print("Numer of grid points:", len(df))
    print("Median variance:", df['variance'].median())
    print("Mean variance:", df['variance'].mean())
    
    print("Median median error:", df['median_error'].median())
    print("Mean mean error:", df['mean_error'].mean())
    
    df['variance'].hist(bins=100,figsize=(12,8))

# %%
df_lake = df_cat.query('clFr_change_is_significant & dl_change_is_significant & not oceanFr_change_is_significant & not si10Fr_change_is_significant')

df_lake['mean_error']=df_lake[selected_cols].mean(axis=1) #mean over the prediciton errors 
df_lake['variance']=df_lake[selected_cols].var(axis=1) #variance over the prediciton errors i.e. noise

# %%
df_lake
# Out:
#         latitude_ERA  longitude_ERA   MODIS_LST  prediction_error_1  \
# 2298      -54.379367     -68.906250  278.404236            2.932979
# 2524      -51.007004     -73.750000  274.123169            4.816545
# 2640      -49.320823     -74.583333  279.504425            4.760699
# 2693      -48.758762     -74.000000  275.387543            3.436432
# 2762      -48.196702     -66.400000  292.468079            2.923074
# ...              ...            ...         ...                 ...
# 149748     70.117048     130.500000  261.509766            3.839574
# 149769     70.117048     146.250000  259.166626            2.950216
# 149770     70.117048     147.000000  259.823456            2.921776
# 149780     70.117048     154.500000  260.750122            3.073905
# 149787     70.117048     159.750000  260.544830            3.031477
#
#         prediction_1  prediction_error_2  prediction_2  prediction_error_3  \
# 2298      276.383575            2.512748    277.031494            2.310007
# 2524      275.111725            5.288032    275.785950            5.167870
# 2640      275.700714            4.083141    276.669220            4.616580
# 2693      276.164429            3.838189    276.796082            3.646682
# 2762      292.568604            3.029530    292.389893            3.116231
# ...              ...                 ...           ...                 ...
# 149748    261.287903            3.760233    260.972443            3.424365
# 149769    260.663452            2.999373    260.977509            2.793789
# 149770    261.298187            3.033228    261.639099            2.826963
# 149780    262.178558            3.093780    262.130035            3.051725
# 149787    260.735657            3.260163    261.164459            3.252664
#
#         prediction_3  prediction_error_4  ...  clFr_change_is_significant  \
# 2298      277.640930            2.243198  ...                        True
# 2524      274.520111            4.902350  ...                        True
# 2640      275.989258            3.996458  ...                        True
# 2693      275.872101            3.621224  ...                        True
# 2762      291.987213            3.274108  ...                        True
# ...              ...                 ...  ...                         ...
# 149748    261.413513            3.878855  ...                        True
# 149769    260.426605            2.807885  ...                        True
# 149770    260.957520            2.843283  ...                        True
# 149780    261.953247            3.153682  ...                        True
# 149787    260.808319            3.227924  ...                        True
#
#         cvhFr_change_is_significant  cvlFr_change_is_significant  \
# 2298                          False                        False
# 2524                          False                        False
# 2640                          False                        False
# 2693                          False                         True
# 2762                          False                        False
# ...                             ...                          ...
# 149748                        False                         True
# 149769                        False                         True
# 149770                        False                         True
# 149780                        False                         True
# 149787                        False                        False
#
#         oceanFr_change_is_significant  si10Fr_change_is_significant  \
# 2298                            False                         False
# 2524                            False                         False
# 2640                            False                         False
# 2693                            False                         False
# 2762                            False                         False
# ...                               ...                           ...
# 149748                          False                         False
# 149769                          False                         False
# 149770                          False                         False
# 149780                          False                         False
# 149787                          False                         False
#
#         dl_change_is_significant  z_change_is_significant  bitstring  \
# 2298                        True                    False    1001000
# 2524                        True                    False    1001000
# 2640                        True                    False    1001000
# 2693                        True                    False    1011000
# 2762                        True                    False    1001000
# ...                          ...                      ...        ...
# 149748                      True                    False    1011000
# 149769                      True                    False    1011000
# 149770                      True                    False    1011000
# 149780                      True                    False    1011000
# 149787                      True                     True    1001001
#
#         mean_error  variance
# 2298      2.499733  0.096559
# 2524      5.043699  0.048898
# 2640      4.364219  0.145045
# 2693      3.635632  0.027013
# 2762      3.085736  0.022011
# ...            ...       ...
# 149748    3.725757  0.042806
# 149769    2.887816  0.010523
# 149770    2.906312  0.008872
# 149780    3.093273  0.001917
# 149787    3.193057  0.011793
#
# [1631 rows x 42 columns]

# %%
import numpy as np 
print(df_lake['mean_error'].mean())
print(np.sqrt(df_lake['variance'].mean()))
# Out:
# 3.1902435
# 0.4261688

# %%
df_lake['variance'].hist(bins=100,figsize=(12,8))
# Out:
# <Axes: >

# %%
df_lake['mean_error'].hist(bins=100,figsize=(12,8))
# Out:
# <Axes: >

# %% [markdown]
# #### Lake ground

# %%
df_lake_ground = df_cat.query('clFr_change_is_significant & dl_change_is_significant & not oceanFr_change_is_significant & not cvhFr_change_is_significant & not cvlFr_change_is_significant')

# %%
surface_noise_numbers(df_lake_ground)
# Out:
# Numer of grid points: 546
# Median variance: 0.02431214600801468
# Mean variance: 0.41963476
# Median median error: 2.9327445030212402
# Mean mean error: 3.953188

# %% [markdown]
# #### Vegetation

# %%
df_vegetation = df_cat.query('cvhFr_change_is_significant & not clFr_change_is_significant')

# %%
df_vegetation
# Out:
#         latitude_ERA  longitude_ERA   MODIS_LST  prediction_error_1  \
# 2502      -51.288034     -73.333333  274.249908            4.092721
# 2670      -49.039793     -72.916667  280.344543            4.903582
# 2695      -48.758762     -73.200000  275.938141            4.156383
# 2722      -48.477732     -72.400000  280.743073            5.803517
# 2771      -47.915672     -72.800000  280.819336            6.250592
# 2818      -47.353611     -73.200000  279.468872            3.568264
# 2844      -47.072581     -73.200000  278.869751            5.801939
# 2873      -46.791551     -73.200000  278.926392            5.143209
# 2903      -46.510520     -73.125000  281.607971            4.764214
# 2933      -46.229490     -73.125000  281.318878            4.167439
# 2967      -45.948460     -73.125000  282.983215            4.566560
# 2968      -45.948460     -72.750000  281.486603            5.547812
# 3145      -44.543308     -72.375000  283.120300            3.477357
# 3182      -44.262278     -72.375000  283.093933            3.104099
# 3300      -43.419187     -72.750000  285.054199            2.486482
# 3301      -43.419187     -72.375000  284.455139            2.753849
# 3384      -42.857127     -72.375000  284.604584            2.589341
# 3462      -42.576096     171.111111  288.086853            1.875457
# 4389      -37.798581     148.666667  293.302063            2.878963
# 19009     -19.812640      44.437500  307.827606            2.698222
# 25432     -13.911003    -171.843750  299.452026            2.413706
# 30656      -8.852456     120.656250  302.146973            2.882368
# 38567      -2.107728     -56.250000  301.184784            4.363639
# 38575      -2.107728     -54.000000  301.163422            3.774287
# 40086      -0.983606      98.718750  299.748657            2.369325
# 40806      -0.421546     132.187500  300.560211            2.529580
# 40926      -0.140515     -50.062500  301.993317            2.341468
# 42655       1.264637     121.218750  301.398285            2.651063
# 42929       1.545667     110.812500  302.889343            2.649512
# 44372       2.950819     112.218750  302.328308            2.433207
# 54269      11.662760     102.937500  302.128815            2.310367
# 69456      22.903974     -83.400000  301.756317            1.931140
# 69914      23.185004     -82.200000  303.754333            3.708010
# 86233      32.459005      34.880000  303.553070            2.983214
# 88884      33.864157     130.560000  294.783661            2.828799
# 89829      34.426218     131.333333  291.155426            2.143995
# 91922      35.831369      -5.666667  299.813995            3.021580
# 95204      37.517551     138.666667  292.633148            3.221752
# 96200      38.079612     139.333333  292.736389            3.737235
# 105108     43.419187      -4.125000  292.058167            2.216050
# 118040     50.444944    -123.750000  274.589813            3.364769
vlFr_change_is_significant  oceanFr_change_is_significant  \
# 2502                           True                          False
# 2670                           True                          False
# 2695                          False                          False
# 2722                          False                          False
# 2771                          False                          False
# 2818                           True                          False
# 2844                          False                          False
# 2873                           True                          False
# 2903                          False                          False
# 2933                          False                          False
# 2967                          False                          False
# 2968                          False                          False
# 3145                          False                          False
# 3182                          False                          False
# 3300                          False                          False
# 3301                          False                          False
# 3384                          False                          False
# 3462                          False                          False
# 4389                          False                          False
# 19009                         False                          False
# 25432                         False                           True
# 30656                         False                          False
# 38567                          True                          False
# 38575                         False                          False
# 40086                         False                          False
# 40806                         False                          False
# 40926                         False                          False
# 42655                         False                          False
# 42929                          True                          False
# 44372                         False                          False
# 54269                         False                          False
# 69456                         False                          False
# 69914                          True                          False
# 86233                         False                          False
# 88884                          True                          False
# 89829                         False                          False
# 91922                          True                          False
# 95204                         False                          False
# 96200                          True                          False
# 105108                        False                          False
# 118040                         True                          False
# 118559                         True                          False
# 119617                         True                          False
# 119618                         True                          False
# 119619                        False                          False
# 120150                         True                          False
# 120151                         True                          False
# 120696                         True                          False
# 122298                        False                          False
# 122806                        False                          False
# 126718                        False                          False
# 134396                         True                          False
# 134472                        False                          False
# 134563                         True                          False
# 135352                        False                          False
# 140955                         True                          False
# 140986                        False                          False
# 144228                         True                          False
#
#         si10Fr_change_is_significant  dl_change_is_significant  \
# 2502                            True                      True
# 2670                            True                      True
# 2695                            True                      True
# 2722                            True                      True
# 2771                            True                      True
# 2818                            True                      True
# 2844                            True                      True
# 2873                           False                      True
# 2903                           False                      True
# 2933                           False                      True
# 2967                           False                      True
# 2968                           False                      True
# 3145                            True                      True
# 3182                            True                      True
# 3300                            True                      True
# 3301                            True                      True
# 3384                            True                      True
# 3462                           False                     False
# 4389                           False                      True
# 19009                          False                      True
# 25432                          False                      True
# 30656                          False                      True
# 38567                          False                      True
# 38575                          False                      True
# 40086                          False                      True
# 40806                          False                      True
# 40926                          False                      True
# 42655                          False                      True
# 42929                          False                      True
# 44372                          False                      True
# 54269                          False                      True
# 69456                          False                      True
# 69914                          False                      True
# 86233                          False                      True
# 88884                          False                     False
# 89829                          False                      True
# 91922                          False                      True
# 95204                          False                      True
# 96200                          False                      True
# 105108                         False                      True
# 118040                          True                      True
# 118559                          True                      True
# 119617                          True                      True
# 119618                          True                     False
# 119619                          True                     False
# 120150                          True                      True
# 120151                          True                     False
# 120696                          True                      True
# 122298                          True                      True
# 122806                          True                      True
# 126718                          True                      True
# 134396                         False                      True
# 134472                         False                      True
# 134563                         False                     False
# 135352                         False                      True
# 140955                         False                      True
# 140986                         False                      True
# 144228                         False                      True
#
#         z_change_is_significant  bitstring  variance  median_error  mean_error
# 2502                      False    0111010  0.042779      4.195994    4.261001
# 2670                      False    0111010  0.556002      4.651009    4.674855
# 2695                      False    0101010  0.749186      4.511899    4.354863
# 2722                      False    0101010  0.330017      4.692355    4.945923
# 2771                      False    0101010  0.389109      5.791768    5.673394
# 2818                      False    0111010  0.429527      4.074640    4.062986
# 2844                      False    0101010  0.504544      6.023121    5.818810
# 2873                      False    0111000  4.520893      5.586582    6.126307
# 2903                      False    0101000  0.602021      5.232566    5.105439
# %% [markdown]
# #### Deep dive on individual bad points

# %%
lake_natron = df_lake.query('latitude_ERA == -2.3887580539270044 & longitude_ERA == 36.0000')
lake_natron_northern_edge =df_lake.query('latitude_ERA == -2.10772769472398 & longitude_ERA == 36.0000') 
lake_blanche =df_lake.query('latitude_ERA ==  -29.367671674745356 & longitude_ERA == 139.6875') 
salt_lake_city =df_lake.query('latitude_ERA ==  41.17094491970063 & longitude_ERA ==  -113.39999999999998') 
farah_province =df_lake.query('latitude_ERA ==  31.615914311651938 & longitude_ERA == 61.120000000000005') 
gujarat_province =df_lake.query('latitude_ERA ==  24.028095261448925 & longitude_ERA ==  69.0') 
toshka_lakes =df_lake.query('latitude_ERA ==  23.18500423251539 & longitude_ERA ==  30.900000000000006') 
all_northern_canada_points = df_lake.query('50.0 < latitude_ERA & -130 < longitude_ERA < -80')

caspain_1 = df_lake.query('latitude_ERA ==  46.22948997297545 & longitude_ERA ==   49.125')
caspain_2 = df_lake.query('latitude_ERA ==  46.22948997297545 & longitude_ERA ==    49.5')
caspain_3 = df_lake.query('latitude_ERA ==  46.51052023808231 & longitude_ERA ==    49.5')
caspain_4 = df_lake.query('latitude_ERA ==  47.072580762649004 & longitude_ERA ==    51.599999999999994')

caspian_edge = pd.concat([caspain_1,caspain_2,caspain_3,caspain_4])

bering_glacier = df_glacier.query('latitude_ERA == 60.280999861571715   & longitude_ERA ==    -143.4666666666667')
juncal_glacier = df_glacier.query('latitude_ERA == -33.021065936911214   & longitude_ERA ==    -70.07999999999998')

# %%
selected_dfs = dict({'lake_natron':lake_natron,
                     'lake_natron_northern_edge':lake_natron_northern_edge,
                     'lake_blanche':lake_blanche,
                     'salt_lake_city':salt_lake_city,
                     'farah_province':farah_province,
                     'gujarat_province':gujarat_province,
                     'toshka_lakes':toshka_lakes,
                     'all_northern_canada_points':all_northern_canada_points,
                     'caspian_edge':caspian_edge,
                     'bering_glacier':bering_glacier,
                     'juncal_glacier':juncal_glacier})

# %%
for key,value in selected_dfs.items():
    print(key)
    surface_noise_numbers(value)
    print("************************")
# Out:
# lake_natron
# Numer of grid points: 1
# Median variance: 0.019072890281677246
# Mean variance: 0.01907289
# Median median error: 3.610163688659668
# Mean mean error: 3.6042576
# ************************
# lake_natron_northern_edge
# Numer of grid points: 1
# Median variance: 0.022181862965226173
# Mean variance: 0.022181863
# Median median error: 3.132234573364258
# Mean mean error: 3.10576
# ************************
# lake_blanche
# Numer of grid points: 1
# Median variance: 0.9169919490814209
# Mean variance: 0.91699195
# Median median error: 3.2879390716552734
# Mean mean error: 3.6252828
# ************************
# salt_lake_city
# Numer of grid points: 1
# Median variance: 0.0896233394742012
# Mean variance: 0.08962334
# Median median error: 3.876434803009033
# Mean mean error: 3.967183
# ************************
# farah_province
# Numer of grid points: 1
# Median variance: 0.0002551457437220961
# Mean variance: 0.00025514574
# Median median error: 2.87972092628479
# Mean mean error: 2.8749602
# ************************
# gujarat_province
# Numer of grid points: 1
# Median variance: 8.630967140197754
# Mean variance: 8.630967
# Median median error: 5.3715949058532715
# Mean mean error: 6.7844563
# ************************
# toshka_lakes
# Numer of grid points: 1
# Median variance: 1.1083770990371704
# Mean variance: 1.1083771
# Median median error: 3.524153232574463
# Mean mean error: 3.6072667
# ************************
# all_northern_canada_points
# Numer of grid points: 756
# Median variance: 0.005416114814579487
# Mean variance: 0.007971809
# Median median error: 2.5528769493103027
# Mean mean error: 2.574009
# ************************
# caspian_edge
# Numer of grid points: 4
# Median variance: 0.04191146418452263
# Mean variance: 0.03920798
# Median median error: 3.17696475982666
# Mean mean error: 3.19443
# ************************
# bering_glacier
# Numer of grid points: 1
# Median variance: 0.3530745208263397
# Mean variance: 0.35307452
# Median median error: 4.464813232421875
# Mean mean error: 4.362267
# ************************
# juncal_glacier
# Numer of grid points: 1
# Median variance: 0.607727587223053
# Mean variance: 0.6077276
# Median median error: 4.075220584869385
# Mean mean error: 4.182169
# ************************

# %%
toshka_lakes[['MODIS_LST', 'prediction_1','prediction_2','prediction_3','prediction_4']]
# Out:
#         MODIS_LST  prediction_1  prediction_2  prediction_3  prediction_4
# 70081  318.107666    316.439697    314.425262    316.792664    313.698792

# %%
gujarat_province[['MODIS_LST', 'prediction_1','prediction_2','prediction_3','prediction_4']]
# Out:
#         MODIS_LST  prediction_1  prediction_2  prediction_3  prediction_4
# 71526  313.741486    309.216736    309.648285    302.657593    309.395355

# %%
gujarat_province
# Out:
#        latitude_ERA  longitude_ERA   MODIS_LST  prediction_error_1  \
# 71526     24.028095           69.0  313.741486            5.290875
#
#        prediction_1  prediction_error_2  prediction_2  prediction_error_3  \
# 71526    309.216736            5.206067    309.648285           11.188568
#
#        prediction_3  prediction_error_4  ...  changeAbs_V20V15_z  \
# 71526    302.657593            5.452314  ...            0.267944
#
#        clFr_change_is_significant  cvhFr_change_is_significant  \
# 71526                        True                        False
#
#        cvlFr_change_is_significant  oceanFr_change_is_significant  \
# 71526                        False                          False
#
#        si10Fr_change_is_significant  dl_change_is_significant  \
# 71526                         False                      True
#
#        z_change_is_significant  bitstring  variance
# 71526                     True    1001001  8.630967
#
# [1 rows x 41 columns]

# %%
gujarat_province
# Out:
#        latitude_ERA  longitude_ERA   MODIS_LST  prediction_error_1  \
# 71526     24.028095           69.0  313.741486            5.290875
#
#        prediction_1  prediction_error_2  prediction_2  prediction_error_3  \
# 71526    309.216736            5.206067    309.648285           11.188568
#
#        prediction_3  prediction_error_4  ...  changeAbs_V20V15_z  \
# 71526    302.657593            5.452314  ...            0.267944
#
#        clFr_change_is_significant  cvhFr_change_is_significant  \
# 71526                        True                        False
#
#        cvlFr_change_is_significant  oceanFr_change_is_significant  \
# 71526                        False                          False
#
#        si10Fr_change_is_significant  dl_change_is_significant  \
# 71526                         False                      True
#
#        z_change_is_significant  bitstring  variance
# 71526                     True    1001001  8.630967
#
# [1 rows x 41 columns]

# %%
juncal_glacier['longitude_ERA'].to_numpy()[0]
# Out:
# -70.07999999999998

# %%
juncal_glacier
# Out:
#       latitude_ERA  longitude_ERA   MODIS_LST  prediction_error_1  \
# 6228    -33.021066         -70.08  290.502838            4.377077
#
#       prediction_1  prediction_error_2  prediction_2  prediction_error_3  \
# 6228    289.279449            3.396034    289.043396            3.773364
#
#       prediction_3  prediction_error_4  ...  changeAbs_V20V15_z  \
# 6228    289.165131            5.182201  ...            0.957031
#
#       clFr_change_is_significant  cvhFr_change_is_significant  \
# 6228                       False                        False
#
#       cvlFr_change_is_significant  oceanFr_change_is_significant  \
# 6228                        False                          False
#
#       si10Fr_change_is_significant  dl_change_is_significant  \
# 6228                          True                      True
#
#       z_change_is_significant  bitstring  variance
# 6228                    False    0001010  0.607728
#
# [1 rows x 41 columns]
