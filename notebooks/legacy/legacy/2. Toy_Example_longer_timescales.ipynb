# %% [markdown]
# # Machine Learning for Land Models (ML4Land)
#
# This notebook is a progression of the methods described in `1. Toy_Example.ipynb`
#
# We use the same data sources, but now rather than at a single timesnap, we use a longer time range to avoid temporal/spatial correlations.
#
# We will take the first 3 months of 2017 in as a traning set and the subsequent two months as a validate/test split respecitvely.
#
# For now this is just to ensure the machinery works. We will then look at doing this for longer times.
#
# Note that when running remotely over SSH, a simple function of the form
#
# ```python
# fig = plt.figure(figsize=(24,12))
# ax = fig.add_subplot(111,projection=ccrs.PlateCarree(central_longitude=0))
# ax.coastlines()
# plt.show()
# ```
#
# fails, for reasons unlnown (seems to kill kernel). Example geo plots can be found in  `1. Toy_Example.ipynb`. Here insteead we will just deal with numbers and dfs.
#
# ---

# %% [markdown]
# ## 1. Getting the X data <a name="features"></a>
#
# As before, we will get our features  via the [Copernicus Climate Data Store](https://cds.climate.copernicus.eu/cdsapp#!/dataset/reanalysis-era5-land-monthly-means?tab=overview).

# %%
import climetlab as cml
import xarray as xr



data_root = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/' #for IO

variables = ['2m_temperature','10m_u_component_of_wind', '10m_v_component_of_wind'] #Variables we are interested in

#Time selection
years = ['2017']
months = ['01','02','03','04','05']
times= ["00:00"]


#Load the data

load_from_remote = True
if load_from_remote:
    xdata = cml.load_source("cds",
                            "reanalysis-era5-land-monthly-means",
                             variable=variables,
                             product_type= "monthly_averaged_reanalysis",
                             year = years,
                             month = months,
                             time = times
                             )
    cds_xarray = xdata.to_xarray(backend_kwargs={'errors': 'ignore','filter_by_keys':{'edition': 1, 'typeOfLevel':'surface'}})
    cds_xarray.to_netcdf(data_root+"xdata.nc")
else:
    cds_xarray = xr.open_dataset(data_root+"xdata.nc")

# %%
display(cds_xarray)
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 5, latitude: 1801, longitude: 3600)
# Coordinates:
#     number      int64 ...
#   * time        (time) datetime64[ns] 2017-01-01 2017-02-01 ... 2017-05-01
#     step        timedelta64[ns] ...
#     surface     float64 ...
#   * latitude    (latitude) float64 90.0 89.9 89.8 89.7 ... -89.8 -89.9 -90.0
#   * longitude   (longitude) float64 0.0 0.1 0.2 0.3 ... 359.6 359.7 359.8 359.9
#     valid_time  (time) datetime64[ns] dask.array<chunksize=(5,), meta=np.ndarray>
# Data variables:
#     t2m         (time, latitude, longitude) float32 dask.array<chunksize=(5, 1801, 3600), meta=np.ndarray>
#     u10         (time, latitude, longitude) float32 dask.array<chunksize=(5, 1801, 3600), meta=np.ndarray>
#     v10         (time, latitude, longitude) float32 dask.array<chunksize=(5, 1801, 3600), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2021-10-29T13:18 GRIB to CDM+CF via cfgrib-0.9.9...

# %% [markdown]
# Unlike before, we now have extra contributions to the `time` dimension that need to be selected for explicitly.
#
# Recall that can select from the xarray dataset as:
# ```python
# cds_xarray.loc[dict(time=slice("2018-01-01"))]
# ```
#
# or from a df in the usual way as:
# ```python
# df_cds = cds_xarray.to_dataframe()
# df_cds.loc["2018-01-01"]
# ```
#
# Before moving forward, lets make the  data into a nice pandas object:

# %%
df_cds = cds_xarray.to_dataframe()

# %%
new = df_cds.query("time=='2017-01-01' | time=='2017-02-01'")
new = df_cds.query("'2017-01-01' <= time <= '2017-03-01'")

# %%
import numpy as np
np.unique(new.index.get_level_values('time'))
# Out:
# array(['2017-01-01T00:00:00.000000000', '2017-02-01T00:00:00.000000000',
#        '2017-03-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# ## 2. Getting the Y data <a name="ydata"></a>
#
# Again we will get the CMG monthly product from MODIS
#
# * [MODIS](https://modis-land.gsfc.nasa.gov/temp.html).
#
# * [MOD11C3](https://lpdaac.usgs.gov/products/mod11c3v006/)
#
# We need to do multiple HTTPS queries, once for each month.
#
# To do this we will first create a text file that can then be read by `wget`:

# %%
base = 'https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/' 
    
    
years = ['2017']
months = ['01','02','03','04','05']

f = open('get_MODIS_data.txt','w')
for y in years:
    for m in months:
        date = y+'.'+m+'.01/ \n'
        string = base+date
        f.write(string)
f.close()

# %% [markdown]
# And then pass this to `wget`:

# %%
# !wget -r -l1 --no-parent -A "*.hdf" -i get_MODIS_data.txt -P "/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/"
# Out:
# --2021-10-29 13:29:47--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/
# Resolving e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)... 152.61.133.130, 2001:49c8:4000:127d::133:130
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:29:57 (5.42 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html.tmp’ saved [3060]
#
# Loading robots.txt; please ignore errors.
# --2021-10-29 13:29:57--  https://e4ftl01.cr.usgs.gov/robots.txt
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://urs.earthdata.nasa.gov/oauth/authorize?scope=uid&app_type=401&client_id=ijpRZvb9qeKCK5ctsn75Tg&response_type=code&redirect_uri=https%3A%2F%2Fe4ftl01.cr.usgs.gov%2Foauth&state=aHR0cHM6Ly9lNGZ0bDAxLmNyLnVzZ3MuZ292L3JvYm90cy50eHQ [following]
# --2021-10-29 13:29:57--  https://urs.earthdata.nasa.gov/oauth/authorize?scope=uid&app_type=401&client_id=ijpRZvb9qeKCK5ctsn75Tg&response_type=code&redirect_uri=https%3A%2F%2Fe4ftl01.cr.usgs.gov%2Foauth&state=aHR0cHM6Ly9lNGZ0bDAxLmNyLnVzZ3MuZ292L3JvYm90cy50eHQ
# Resolving urs.earthdata.nasa.gov (urs.earthdata.nasa.gov)... 198.118.243.33, 2001:4d0:241a:4081::89
# Connecting to urs.earthdata.nasa.gov (urs.earthdata.nasa.gov)|198.118.243.33|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Please enter your Earthdata Login credentials. If you do not have a Earthdata Login, create one at https://urs.earthdata.nasa.gov//users/new"
# Reusing existing connection to urs.earthdata.nasa.gov:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://e4ftl01.cr.usgs.gov/oauth?code=6b369462643af2cd1ea212968bd12481713395c3d7e505a9051a5c44bfee4c2f&state=aHR0cHM6Ly9lNGZ0bDAxLmNyLnVzZ3MuZ292L3JvYm90cy50eHQ [following]
# --2021-10-29 13:29:59--  https://e4ftl01.cr.usgs.gov/oauth?code=6b369462643af2cd1ea212968bd12481713395c3d7e505a9051a5c44bfee4c2f&state=aHR0cHM6Ly9lNGZ0bDAxLmNyLnVzZ3MuZ292L3JvYm90cy50eHQ
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://e4ftl01.cr.usgs.gov/robots.txt [following]
# --2021-10-29 13:30:07--  https://e4ftl01.cr.usgs.gov/robots.txt
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-10-29 13:30:15 ERROR 404: Not Found.
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html.tmp since it should be rejected.
#
# --2021-10-29 13:30:15--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/?C=N;O=D
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=N;O=D.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:30:16 (4.86 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=N;O=D.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2021-10-29 13:30:16--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/?C=M;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=M;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0s
#
# 2021-10-29 13:30:16 (7.07 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=M;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:30:16--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/?C=S;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=S;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:30:16 (4.02 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=S;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:30:16--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/?C=D;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=D;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:30:16 (5.57 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=D;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:30:16--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/MOD11C3.A2017001.006.2017032204847.hdf
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70314982 (67M) [application/x-hdf]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/MOD11C3.A2017001.006.2017032204847.hdf’
#
# e4ftl01.cr.usgs.gov 100%[===================>]  67.06M   672KB/s    in 1m 52s
#
# 2021-10-29 13:32:09 (612 KB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/MOD11C3.A2017001.006.2017032204847.hdf’ saved [70314982/70314982]
#
# --2021-10-29 13:32:09--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.05s
#
# 2021-10-29 13:32:18 (59.4 KB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html.tmp since it should be rejected.
#
# --2021-10-29 13:32:18--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/?C=N;O=D
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=N;O=D.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:32:18 (5.42 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=N;O=D.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2021-10-29 13:32:18--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/?C=M;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=M;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:32:18 (5.23 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=M;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:32:18--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/?C=S;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=S;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:32:18 (5.69 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=S;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:32:18--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/?C=D;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=D;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:32:19 (5.36 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=D;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:32:19--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/MOD11C3.A2017032.006.2017062155051.hdf
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 71405505 (68M) [application/x-hdf]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/MOD11C3.A2017032.006.2017062155051.hdf’
#
# e4ftl01.cr.usgs.gov 100%[===================>]  68.10M   505KB/s    in 2m 11s
#
# 2021-10-29 13:34:30 (534 KB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.02.01/MOD11C3.A2017032.006.2017062155051.hdf’ saved [71405505/71405505]
#
# --2021-10-29 13:34:30--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:34:38 (5.76 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html.tmp since it should be rejected.
#
# --2021-10-29 13:34:38--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/?C=N;O=D
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=N;O=D.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:34:38 (5.64 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=N;O=D.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2021-10-29 13:34:38--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/?C=M;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=M;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:34:38 (5.30 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=M;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:34:38--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/?C=S;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=S;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0s
#
# 2021-10-29 13:34:39 (8.48 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=S;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:34:39--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/?C=D;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=D;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:34:39 (5.46 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=D;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:34:39--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/MOD11C3.A2017060.006.2017092184027.hdf
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 74314368 (71M) [application/x-hdf]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/MOD11C3.A2017060.006.2017092184027.hdf’
#
# e4ftl01.cr.usgs.gov 100%[===================>]  70.87M   545KB/s    in 83s
#
# 2021-10-29 13:36:02 (879 KB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.03.01/MOD11C3.A2017060.006.2017092184027.hdf’ saved [74314368/74314368]
#
# --2021-10-29 13:36:02--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:36:10 (3.89 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html.tmp since it should be rejected.
#
# --2021-10-29 13:36:10--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/?C=N;O=D
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=N;O=D.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:36:11 (5.07 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=N;O=D.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2021-10-29 13:36:11--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/?C=M;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=M;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:36:11 (5.54 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=M;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:36:11--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/?C=S;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=S;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0s
#
# 2021-10-29 13:36:11 (5.90 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=S;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:36:11--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/?C=D;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=D;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:36:11 (5.59 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=D;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:36:11--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/MOD11C3.A2017091.006.2017128142739.hdf
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 73769437 (70M) [application/x-hdf]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/MOD11C3.A2017091.006.2017128142739.hdf’
#
# e4ftl01.cr.usgs.gov 100%[===================>]  70.35M   649KB/s    in 2m 6s
#
# 2021-10-29 13:38:18 (572 KB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.04.01/MOD11C3.A2017091.006.2017128142739.hdf’ saved [73769437/73769437]
#
# --2021-10-29 13:38:18--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:38:25 (5.14 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html.tmp since it should be rejected.
#
# --2021-10-29 13:38:25--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/?C=N;O=D
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=N;O=D.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0s
#
# 2021-10-29 13:38:25 (8.28 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=N;O=D.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2021-10-29 13:38:25--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/?C=M;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=M;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:38:25 (5.59 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=M;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:38:25--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/?C=S;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=S;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:38:25 (5.75 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=S;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:38:25--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/?C=D;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=D;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:38:26 (5.79 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=D;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:38:26--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/MOD11C3.A2017121.006.2017162222451.hdf
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 74438533 (71M) [application/x-hdf]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/MOD11C3.A2017121.006.2017162222451.hdf’
#
# e4ftl01.cr.usgs.gov 100%[===================>]  70.99M   829KB/s    in 2m 0s
#
# 2021-10-29 13:40:26 (608 KB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.05.01/MOD11C3.A2017121.006.2017162222451.hdf’ saved [74438533/74438533]
#
# --2021-10-29 13:40:26--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:40:33 (4.37 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html.tmp since it should be rejected.
#
# --2021-10-29 13:40:33--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/?C=N;O=D
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=N;O=D.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:40:33 (4.11 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=N;O=D.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2021-10-29 13:40:33--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/?C=M;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=M;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:40:33 (5.61 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=M;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:40:33--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/?C=S;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=S;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0s
#
# 2021-10-29 13:40:33 (5.84 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=S;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:40:33--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/?C=D;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=D;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:40:33 (5.46 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=D;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:40:33--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/MOD11C3.A2018001.006.2018032091151.hdf
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70044511 (67M) [application/x-hdf]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/MOD11C3.A2018001.006.2018032091151.hdf’
#
# e4ftl01.cr.usgs.gov 100%[===================>]  66.80M   620KB/s    in 2m 55s
#
# 2021-10-29 13:43:29 (390 KB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.01.01/MOD11C3.A2018001.006.2018032091151.hdf’ saved [70044511/70044511]
#
# --2021-10-29 13:43:29--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0s
#
# 2021-10-29 13:43:36 (6.14 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html.tmp since it should be rejected.
#
# --2021-10-29 13:43:36--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/?C=N;O=D
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=N;O=D.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:43:37 (5.10 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=N;O=D.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2021-10-29 13:43:37--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/?C=M;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=M;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0s
#
# 2021-10-29 13:43:37 (5.84 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=M;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:43:37--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/?C=S;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=S;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:43:37 (5.37 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=S;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:43:37--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/?C=D;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=D;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:43:37 (5.70 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=D;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:43:37--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/MOD11C3.A2018032.006.2018060085728.hdf
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 72251854 (69M) [application/x-hdf]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/MOD11C3.A2018032.006.2018060085728.hdf’
#
# e4ftl01.cr.usgs.gov 100%[===================>]  68.90M  2.31MB/s    in 93s
#
# 2021-10-29 13:45:10 (760 KB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.02.01/MOD11C3.A2018032.006.2018060085728.hdf’ saved [72251854/72251854]
#
# --2021-10-29 13:45:10--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:45:17 (5.14 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html.tmp since it should be rejected.
#
# --2021-10-29 13:45:17--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/?C=N;O=D
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=N;O=D.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:45:17 (5.08 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=N;O=D.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2021-10-29 13:45:17--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/?C=M;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=M;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:45:17 (5.68 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=M;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:45:17--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/?C=S;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=S;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:45:18 (4.22 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=S;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:45:18--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/?C=D;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=D;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:45:18 (3.82 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=D;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:45:18--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/MOD11C3.A2018060.006.2018093182920.hdf
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 74507515 (71M) [application/x-hdf]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/MOD11C3.A2018060.006.2018093182920.hdf’
#
# e4ftl01.cr.usgs.gov 100%[===================>]  71.06M  1.59MB/s    in 88s
#
# 2021-10-29 13:46:46 (831 KB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.03.01/MOD11C3.A2018060.006.2018093182920.hdf’ saved [74507515/74507515]
#
# --2021-10-29 13:46:46--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:46:53 (5.33 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html.tmp since it should be rejected.
#
# --2021-10-29 13:46:53--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/?C=N;O=D
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=N;O=D.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:46:53 (5.01 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=N;O=D.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2021-10-29 13:46:53--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/?C=M;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=M;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:46:53 (4.87 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=M;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:46:53--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/?C=S;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=S;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:46:53 (5.35 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=S;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:46:53--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/?C=D;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=D;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:46:54 (5.26 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=D;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:46:54--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/MOD11C3.A2018091.006.2018121150952.hdf
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 73176242 (70M) [application/x-hdf]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/MOD11C3.A2018091.006.2018121150952.hdf’
#
# e4ftl01.cr.usgs.gov 100%[===================>]  69.79M   946KB/s    in 96s
#
# 2021-10-29 13:48:30 (743 KB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.04.01/MOD11C3.A2018091.006.2018121150952.hdf’ saved [73176242/73176242]
#
# --2021-10-29 13:48:30--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:48:38 (2.91 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html.tmp since it should be rejected.
#
# --2021-10-29 13:48:38--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/?C=N;O=D
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=N;O=D.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:48:38 (4.42 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=N;O=D.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2021-10-29 13:48:38--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/?C=M;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=M;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:48:39 (4.71 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=M;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:48:39--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/?C=S;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=S;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:48:39 (5.55 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=S;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:48:39--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/?C=D;O=A
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=D;O=A.tmp’
#
# e4ftl01.cr.usgs.gov     [ <=>                ]   2.99K  --.-KB/s    in 0.001s
#
# 2021-10-29 13:48:39 (4.70 MB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=D;O=A.tmp’ saved [3060]
#
# Removing /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2021-10-29 13:48:39--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/MOD11C3.A2018121.006.2018153093002.hdf
# Reusing existing connection to e4ftl01.cr.usgs.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 73516623 (70M) [application/x-hdf]
# Saving to: ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/MOD11C3.A2018121.006.2018153093002.hdf’
#
# e4ftl01.cr.usgs.gov 100%[===================>]  70.11M  1.14MB/s    in 96s
#
# 2021-10-29 13:50:15 (747 KB/s) - ‘/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2018.05.01/MOD11C3.A2018121.006.2018153093002.hdf’ saved [73516623/73516623]
#
# FINISHED --2021-10-29 13:50:15--
# Total wall clock time: 20m 28s
# Downloaded: 60 files, 694M in 18m 39s (635 KB/s)

# %% [markdown]
# Each file is saved within a nest of directories - maybe there is a way to modiy wget to avoid this?
#
# In any case it is no real problem; we can easily access the relevant files through `glob`
#
# Lets bring all this data together into a single df

# %%
import xarray as xr
import rioxarray as rxr
import glob
import pandas as pd
import sys
all_files = glob.glob('/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/**/*.hdf')

dfs = []
for f in (all_files):
    modis_xarray= rxr.open_rasterio(f,masked=True)
    datastamp = modis_xarray.attrs['RANGEBEGINNINGDATE']
    modis_df = modis_xarray.to_dataframe() #everything as a df
    modis_df['time'] = datastamp

    modis_df = modis_df[['LST_Day_CMG', 'time']] 

    dfs.append(modis_df)

df_modis = pd.concat(dfs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<function open at 0x7f21c7a80670>, ('/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/MOD11C3.A2017001.006.2017032204847.hdf',), 'r', (('sharing', False),)]
#
# During handling of the above exception, another exception occurred:
#
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_shim.pyx in rasterio._shim.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/MOD11C3.A2017001.006.2017032204847.hdf' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-21-c0aad3af7893> in <module>
#       8 dfs = []
#       9 for f in (all_files):
# ---> 10     modis_xarray= rxr.open_rasterio(f,masked=True)
#      11     datastamp = modis_xarray.attrs['RANGEBEGINNINGDATE']
#      12     modis_df = modis_xarray.to_dataframe() #everything as a df
#
# ~/anaconda3/lib/python3.8/site-packages/rioxarray/_io.py in open_rasterio(filename, parse_coordinates, chunks, cache, lock, masked, mask_and_scale, variable, group, default_name, decode_times, decode_timedelta, **open_kwargs)
#     831         else:
#     832             manager = URIManager(rasterio.open, filename, mode="r", kwargs=open_kwargs)
# --> 833         riods = manager.acquire()
#     834         captured_warnings = rio_warnings.copy()
#     835
#
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in acquire(self, needs_lock)
#     179             An open file object, as returned by ``opener(*args, **kwargs)``.
#     180         """
# --> 181         file, _ = self._acquire_with_cache_info(needs_lock)
#     182         return file
#     183
#
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# ~/anaconda3/lib/python3.8/site-packages/rasterio/env.py in wrapper(*args, **kwds)
#     435
#     436         with env_ctor(session=session):
# --> 437             return f(*args, **kwds)
#     438
#     439     return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     218         # None.
#     219         if mode == 'r':
# --> 220             s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     221         elif mode == "r+":
#     222             s = get_writer_for_path(path, driver=driver)(
#
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2017.01.01/MOD11C3.A2017001.006.2017032204847.hdf' not recognized as a supported file format.

# %%
import rioxarray as rxr
rxr.open_rasterio('true_y_data.hdf')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<function open at 0x7f916b4be280>, ('true_y_data.hdf',), 'r', (('sharing', False),)]
#
# During handling of the above exception, another exception occurred:
#
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_shim.pyx in rasterio._shim.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: 'true_y_data.hdf' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-2-d28901160a7f> in <module>
#       1 import rioxarray as rxr
# ----> 2 rxr.open_rasterio('true_y_data.hdf')
#
# ~/anaconda3/lib/python3.8/site-packages/rioxarray/_io.py in open_rasterio(filename, parse_coordinates, chunks, cache, lock, masked, mask_and_scale, variable, group, default_name, decode_times, decode_timedelta, **open_kwargs)
#     831         else:
#     832             manager = URIManager(rasterio.open, filename, mode="r", kwargs=open_kwargs)
# --> 833         riods = manager.acquire()
#     834         captured_warnings = rio_warnings.copy()
#     835
#
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in acquire(self, needs_lock)
#     179             An open file object, as returned by ``opener(*args, **kwargs)``.
#     180         """
# --> 181         file, _ = self._acquire_with_cache_info(needs_lock)
#     182         return file
#     183
#
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# ~/anaconda3/lib/python3.8/site-packages/rasterio/env.py in wrapper(*args, **kwds)
#     435
#     436         with env_ctor(session=session):
# --> 437             return f(*args, **kwds)
#     438
#     439     return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     218         # None.
#     219         if mode == 'r':
# --> 220             s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     221         elif mode == "r+":
#     222             s = get_writer_for_path(path, driver=driver)(
#
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: 'true_y_data.hdf' not recognized as a supported file format.

# %%
! wget https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2016.01.01/MOD11C3.A2016001.006.2016234032549.hdf -O ../data/ydata2.hdf
# Out:
# --2021-10-29 14:17:32--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2016.01.01/MOD11C3.A2016001.006.2016234032549.hdf
# Resolving e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)... 152.61.133.130, 2001:49c8:4000:127d::133:130
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://urs.earthdata.nasa.gov/oauth/authorize?scope=uid&app_type=401&client_id=ijpRZvb9qeKCK5ctsn75Tg&response_type=code&redirect_uri=https%3A%2F%2Fe4ftl01.cr.usgs.gov%2Foauth&state=aHR0cHM6Ly9lNGZ0bDAxLmNyLnVzZ3MuZ292L01PTFQvTU9EMTFDMy4wMDYvMjAxNi4wMS4wMS9NT0QxMUMzLkEyMDE2MDAxLjAwNi4yMDE2MjM0MDMyNTQ5LmhkZg [following]
# --2021-10-29 14:17:39--  https://urs.earthdata.nasa.gov/oauth/authorize?scope=uid&app_type=401&client_id=ijpRZvb9qeKCK5ctsn75Tg&response_type=code&redirect_uri=https%3A%2F%2Fe4ftl01.cr.usgs.gov%2Foauth&state=aHR0cHM6Ly9lNGZ0bDAxLmNyLnVzZ3MuZ292L01PTFQvTU9EMTFDMy4wMDYvMjAxNi4wMS4wMS9NT0QxMUMzLkEyMDE2MDAxLjAwNi4yMDE2MjM0MDMyNTQ5LmhkZg
# Resolving urs.earthdata.nasa.gov (urs.earthdata.nasa.gov)... 198.118.243.33, 2001:4d0:241a:4081::89
# Connecting to urs.earthdata.nasa.gov (urs.earthdata.nasa.gov)|198.118.243.33|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Please enter your Earthdata Login credentials. If you do not have a Earthdata Login, create one at https://urs.earthdata.nasa.gov//users/new"
# Reusing existing connection to urs.earthdata.nasa.gov:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://e4ftl01.cr.usgs.gov/oauth?code=6f322f4a9936f315a6123d590589bf5f949a71cd1d315e37054a29ba7bb9ed14&state=aHR0cHM6Ly9lNGZ0bDAxLmNyLnVzZ3MuZ292L01PTFQvTU9EMTFDMy4wMDYvMjAxNi4wMS4wMS9NT0QxMUMzLkEyMDE2MDAxLjAwNi4yMDE2MjM0MDMyNTQ5LmhkZg [following]
# --2021-10-29 14:17:40--  https://e4ftl01.cr.usgs.gov/oauth?code=6f322f4a9936f315a6123d590589bf5f949a71cd1d315e37054a29ba7bb9ed14&state=aHR0cHM6Ly9lNGZ0bDAxLmNyLnVzZ3MuZ292L01PTFQvTU9EMTFDMy4wMDYvMjAxNi4wMS4wMS9NT0QxMUMzLkEyMDE2MDAxLjAwNi4yMDE2MjM0MDMyNTQ5LmhkZg
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2016.01.01/MOD11C3.A2016001.006.2016234032549.hdf [following]
# --2021-10-29 14:17:47--  https://e4ftl01.cr.usgs.gov/MOLT/MOD11C3.006/2016.01.01/MOD11C3.A2016001.006.2016234032549.hdf
# Connecting to e4ftl01.cr.usgs.gov (e4ftl01.cr.usgs.gov)|152.61.133.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73059678 (70M) [application/x-hdf]
# Saving to: ‘../data/ydata2.hdf’
#
# ../data/ydata2.hdf  100%[===================>]  69.67M   496KB/s    in 1m 45s
#
# 2021-10-29 14:19:40 (680 KB/s) - ‘../data/ydata2.hdf’ saved [73059678/73059678]

# %%
f = 'true_y_data.hdf'
rxr.open_rasterio(f,masked=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<function open at 0x7f21c7a80670>, ('true_y_data.hdf',), 'r', (('sharing', False),)]
#
# During handling of the above exception, another exception occurred:
#
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_shim.pyx in rasterio._shim.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: 'true_y_data.hdf' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-34-8ed831c7f7f3> in <module>
#       1 f = 'true_y_data.hdf'
# ----> 2 rxr.open_rasterio(f,masked=True)
#
# ~/anaconda3/lib/python3.8/site-packages/rioxarray/_io.py in open_rasterio(filename, parse_coordinates, chunks, cache, lock, masked, mask_and_scale, variable, group, default_name, decode_times, decode_timedelta, **open_kwargs)
#     831         else:
#     832             manager = URIManager(rasterio.open, filename, mode="r", kwargs=open_kwargs)
# --> 833         riods = manager.acquire()
#     834         captured_warnings = rio_warnings.copy()
#     835
#
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in acquire(self, needs_lock)
#     179             An open file object, as returned by ``opener(*args, **kwargs)``.
#     180         """
# --> 181         file, _ = self._acquire_with_cache_info(needs_lock)
#     182         return file
#     183
#
# ~/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# ~/anaconda3/lib/python3.8/site-packages/rasterio/env.py in wrapper(*args, **kwds)
#     435
#     436         with env_ctor(session=session):
# --> 437             return f(*args, **kwds)
#     438
#     439     return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     218         # None.
#     219         if mode == 'r':
# --> 220             s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     221         elif mode == "r+":
#     222             s = get_writer_for_path(path, driver=driver)(
#
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: 'true_y_data.hdf' not recognized as a supported file format.

# %%
# !conda list
# Out:
# # packages in environment at /home/kimpson/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# _libgcc_mutex             0.1                        main
# affine                    2.3.0                    pypi_0    pypi
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  2021.05                  py38_0
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        2.0.3                    py38_0
# anaconda-project          0.9.1              pyhd3eb1b0_1
# anyio                     2.2.0            py38h06a4308_1
# appdirs                   1.4.4                      py_0
# argh                      0.26.2                   py38_0
# argon2-cffi               20.1.0           py38h27cfd23_1
# asciitree                 0.3.3                    pypi_0    pypi
# asn1crypto                1.4.0                      py_0
# astroid                   2.5              py38h06a4308_1
# astropy                   4.2.1            py38h27cfd23_1
# async_generator           1.10               pyhd3eb1b0_0
# atomicwrites              1.4.0                      py_0
# attrs                     20.3.0             pyhd3eb1b0_0
# autopep8                  1.5.6              pyhd3eb1b0_0
# babel                     2.9.0              pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# backports                 1.0                pyhd3eb1b0_2
# backports.functools_lru_cache 1.6.4              pyhd3eb1b0_0
# backports.shutil_get_terminal_size 1.0.0              pyhd3eb1b0_3
# backports.tempfile        1.0                pyhd3eb1b0_1
# backports.weakref         1.0.post1                  py_1
# beautifulsoup4            4.9.3              pyha847dfd_0
# bitarray                  2.1.0            py38h27cfd23_1
# bkcharts                  0.2                      py38_0
# black                     19.10b0                    py_0
# blas                      1.0                         mkl
# bleach                    3.3.0              pyhd3eb1b0_0
# blosc                     1.21.0               h8c45485_0
# bokeh                     2.3.2            py38h06a4308_0
# boto                      2.49.0                   py38_0
# bottleneck                1.3.2            py38heb32a55_1
# branca                    0.3.1                    pypi_0    pypi
# brotlipy                  0.7.0           py38h27cfd23_1003
# bzip2                     1.0.8                h7b6447c_0
# c-ares                    1.17.1               h27cfd23_0
# ca-certificates           2021.4.13            h06a4308_1
# cairo                     1.16.0               hf32fb01_1
# cartopy                   0.19.0.post1             pypi_0    pypi
# cdsapi                    0.5.1                    pypi_0    pypi
# certifi                   2020.12.5        py38h06a4308_0
# cffi                      1.14.5           py38h261ae71_0
# cfgrib                    0.9.9.0                  pypi_0    pypi
# cftime                    1.5.0                    pypi_0    pypi
# chardet                   4.0.0           py38h06a4308_1003
# click                     7.1.2              pyhd3eb1b0_0
# click-plugins             1.1.1                    pypi_0    pypi
# cligj                     0.7.2                    pypi_0    pypi
# climetlab                 0.8.18                   pypi_0    pypi
# cloudpickle               1.6.0                      py_0
# clyent                    1.2.2                    py38_1
# colorama                  0.4.4              pyhd3eb1b0_0
# conda                     4.10.3           py38h06a4308_0
# conda-build               3.21.4           py38h06a4308_0
# conda-content-trust       0.1.1              pyhd3eb1b0_0
# conda-env                 2.6.0                         1
# conda-package-handling    1.7.3            py38h27cfd23_1
# conda-repo-cli            1.0.4              pyhd3eb1b0_0
# conda-token               0.3.0              pyhd3eb1b0_0
# conda-verify              3.4.2                      py_1
# contextlib2               0.6.0.post1                py_0
# cryptography              3.4.7            py38hd23ed53_0
# curl                      7.71.1               hbc83047_1
# cycler                    0.10.0                   py38_0
# cython                    0.29.23          py38h2531618_0
# cytoolz                   0.11.0           py38h7b6447c_0
# dask                      2021.4.0           pyhd3eb1b0_0
# dask-core                 2021.4.0           pyhd3eb1b0_0
# dbus                      1.13.18              hb2f20db_0
# decorator                 5.0.6              pyhd3eb1b0_0
# defusedxml                0.7.1              pyhd3eb1b0_0
# diff-match-patch          20200713                   py_0
# distributed               2021.4.1         py38h06a4308_0
# docopt                    0.6.2                    pypi_0    pypi
# docutils                  0.17.1           py38h06a4308_1
# eccodes                   1.3.3                    pypi_0    pypi
# ecmwf-api-client          1.6.1                    pypi_0    pypi
# ecmwflibs                 0.3.14                   pypi_0    pypi
# entrypoints               0.3                      py38_0
# et_xmlfile                1.0.1                   py_1001
# expat                     2.3.0                h2531618_2
# fastcache                 1.1.0            py38h7b6447c_0
# fasteners                 0.16.3                   pypi_0    pypi
# filelock                  3.0.12             pyhd3eb1b0_1
# findlibs                  0.0.2                    pypi_0    pypi
# fiona                     1.8.20                   pypi_0    pypi
# flake8                    3.9.0              pyhd3eb1b0_0
# flask                     1.1.2              pyhd3eb1b0_0
# folium                    0.12.1                   pypi_0    pypi
# fontconfig                2.13.1               h6c09931_0
# freetype                  2.10.4               h5ab3b9f_0
# fribidi                   1.0.10               h7b6447c_0
# fsspec                    0.9.0              pyhd3eb1b0_0
# future                    0.18.2                   py38_1
# geopandas                 0.9.0                    pypi_0    pypi
# get_terminal_size         1.0.0                haa9412d_0
# gevent                    21.1.2           py38h27cfd23_1
# glib                      2.68.1               h36276a3_0
# glob2                     0.7                pyhd3eb1b0_0
# gmp                       6.2.1                h2531618_2
# gmpy2                     2.0.8            py38hd5f6e3b_3
# graphite2                 1.3.14               h23475e2_0
# greenlet                  1.0.0            py38h2531618_2
# gst-plugins-base          1.14.0               h8213a91_2
# gstreamer                 1.14.0               h28cd5cc_2
# h5netcdf                  0.11.0                   pypi_0    pypi
# h5py                      2.10.0           py38h7918eee_0
# harfbuzz                  2.8.0                h6f93f22_0
# hdf5                      1.10.4               hb1b8bf9_0
# heapdict                  1.0.1                      py_0
# html5lib                  1.1                        py_0
# icu                       58.2                 he6710b0_3
# idna                      2.10               pyhd3eb1b0_0
# imageio                   2.9.0              pyhd3eb1b0_0
# imagesize                 1.2.0              pyhd3eb1b0_0
# importlib-metadata        3.10.0           py38h06a4308_0
# importlib_metadata        3.10.0               hd3eb1b0_0
# iniconfig                 1.1.1              pyhd3eb1b0_0
# intel-openmp              2021.2.0           h06a4308_610
# intervaltree              3.1.0                      py_0
# ipykernel                 5.3.4            py38h5ca1d4c_0
# ipython                   7.22.0           py38hb070fc8_0
# ipython_genutils          0.2.0              pyhd3eb1b0_1
# ipywidgets                7.6.3              pyhd3eb1b0_1
# isort                     5.8.0              pyhd3eb1b0_0
# itsdangerous              1.1.0              pyhd3eb1b0_0
# jbig                      2.1                  hdba287a_0
# jdcal                     1.4.1                      py_0
# jedi                      0.17.2           py38h06a4308_1
# jeepney                   0.6.0              pyhd3eb1b0_0
# jellyfish                 0.8.8                    pypi_0    pypi
# jinja2                    2.11.3             pyhd3eb1b0_0
# joblib                    1.0.1              pyhd3eb1b0_0
# jpeg                      9b                   h024ee3a_2
# json5                     0.9.5                      py_0
# jsonschema                3.2.0                      py_2
# jupyter                   1.0.0                    py38_7
# jupyter-packaging         0.7.12             pyhd3eb1b0_0
# jupyter_client            6.1.12             pyhd3eb1b0_0
# jupyter_console           6.4.0              pyhd3eb1b0_0
# jupyter_core              4.7.1            py38h06a4308_0
# jupyter_server            1.4.1            py38h06a4308_0
# jupyterlab                3.0.14             pyhd3eb1b0_1
# jupyterlab_pygments       0.1.2                      py_0
# jupyterlab_server         2.4.0              pyhd3eb1b0_0
# jupyterlab_widgets        1.0.0              pyhd3eb1b0_1
# keyring                   22.3.0           py38h06a4308_0
# kiwisolver                1.3.1            py38h2531618_0
# krb5                      1.18.2               h173b8e3_0
# lazy-object-proxy         1.6.0            py38h27cfd23_0
# lcms2                     2.12                 h3be6417_0
# ld_impl_linux-64          2.33.1               h53a641e_7
# libarchive                3.4.2                h62408e4_0
# libcurl                   7.71.1               h20c2e04_1
# libedit                   3.1.20210216         h27cfd23_1
# libev                     4.33                 h7b6447c_0
# libffi                    3.3                  he6710b0_2
# libgcc-ng                 9.1.0                hdf63c60_0
# libgfortran-ng            7.3.0                hdf63c60_0
# liblief                   0.10.1               he6710b0_0
# libllvm10                 10.0.1               hbcb73fb_5
# libpng                    1.6.37               hbc83047_0
# libsodium                 1.0.18               h7b6447c_0
# libspatialindex           1.9.3                h2531618_0
# libssh2                   1.9.0                h1ba5d50_1
# libstdcxx-ng              9.1.0                hdf63c60_0
# libtiff                   4.2.0                h85742a9_0
# libtool                   2.4.6             h7b6447c_1005
# libuuid                   1.0.3                h1bed415_2
# libuv                     1.40.0               h7b6447c_0
# libwebp-base              1.2.0                h27cfd23_0
# libxcb                    1.14                 h7b6447c_0
# libxml2                   2.9.10               hb55368b_3
# libxslt                   1.1.34               hc22bd24_0
# llvmlite                  0.36.0           py38h612dafd_4
# locket                    0.2.1            py38h06a4308_1
# lxml                      4.6.3            py38h9120a33_0
# lz4-c                     1.9.3                h2531618_0
# lzo                       2.10                 h7b6447c_2
# magics                    1.5.6                    pypi_0    pypi
# markdown                  3.3.4                    pypi_0    pypi
# markupsafe                1.1.1            py38h7b6447c_0
# matplotlib                3.3.4            py38h06a4308_0
# matplotlib-base           3.3.4            py38h62a2d02_0
# mccabe                    0.6.1                    py38_1
# mistune                   0.8.4           py38h7b6447c_1000
# mkl                       2021.2.0           h06a4308_296
# mkl-service               2.3.0            py38h27cfd23_1
# mkl_fft                   1.3.0            py38h42c9631_2
# mkl_random                1.2.1            py38ha9443f7_2
# mock                      4.0.3              pyhd3eb1b0_0
# more-itertools            8.7.0              pyhd3eb1b0_0
# mpc                       1.1.0                h10f8cd9_1
# mpfr                      4.0.2                hb69a4c5_1
# mpmath                    1.2.1            py38h06a4308_0
# msgpack-python            1.0.2            py38hff7bd54_1
# multipledispatch          0.6.0                    py38_0
# munch                     2.5.0                    pypi_0    pypi
# mypy_extensions           0.4.3                    py38_0
# navigator-updater         0.2.1                    py38_0
# nbclassic                 0.2.6              pyhd3eb1b0_0
# nbclient                  0.5.3              pyhd3eb1b0_0
# nbconvert                 6.0.7                    py38_0
# nbformat                  5.1.3              pyhd3eb1b0_0
# ncurses                   6.2                  he6710b0_1
# nest-asyncio              1.5.1              pyhd3eb1b0_0
# netcdf4                   1.5.7                    pypi_0    pypi
# networkx                  2.5                        py_0
# nltk                      3.6.1              pyhd3eb1b0_0
# nose                      1.3.7           pyhd3eb1b0_1006
# notebook                  6.3.0            py38h06a4308_0
# numba                     0.53.1           py38ha9443f7_0
# numcodecs                 0.9.1                    pypi_0    pypi
# numexpr                   2.7.3            py38h22e1b3c_1
# numpy                     1.20.1           py38h93e21f0_0
# numpy-base                1.20.1           py38h7d8b39e_0
# numpydoc                  1.1.0              pyhd3eb1b0_1
# olefile                   0.46                       py_0
# openpyxl                  3.0.7              pyhd3eb1b0_0
# openssl                   1.1.1k               h27cfd23_0
# packaging                 20.9               pyhd3eb1b0_0
# pandas                    1.2.4            py38h2531618_0
# pandoc                    2.12                 h06a4308_0
# pandocfilters             1.4.3            py38h06a4308_1
# pango                     1.45.3               hd140c19_0
# parso                     0.7.0                      py_0
# partd                     1.2.0              pyhd3eb1b0_0
# patchelf                  0.12                 h2531618_1
# path                      15.1.2           py38h06a4308_0
# path.py                   12.5.0                        0
# pathlib2                  2.3.5            py38h06a4308_2
# pathspec                  0.7.0                      py_0
# patsy                     0.5.1                    py38_0
# pcre                      8.44                 he6710b0_0
# pdbufr                    0.9.0                    pypi_0    pypi
# pep8                      1.7.1                    py38_0
# pexpect                   4.8.0              pyhd3eb1b0_3
# pickleshare               0.7.5           pyhd3eb1b0_1003
# pillow                    8.2.0            py38he98fc37_0
# pip                       21.0.1           py38h06a4308_0
# pixman                    0.40.0               h7b6447c_0
# pkginfo                   1.7.0            py38h06a4308_0
# pluggy                    0.13.1           py38h06a4308_0
# ply                       3.11                     py38_0
# pooch                     1.5.1                    pypi_0    pypi
# prometheus_client         0.10.1             pyhd3eb1b0_0
# prompt-toolkit            3.0.17             pyh06a4308_0
# prompt_toolkit            3.0.17               hd3eb1b0_0
# psutil                    5.8.0            py38h27cfd23_1
# ptyprocess                0.7.0              pyhd3eb1b0_2
# py                        1.10.0             pyhd3eb1b0_0
# py-lief                   0.10.1           py38h403a769_0
# pycodestyle               2.6.0              pyhd3eb1b0_0
# pycosat                   0.6.3            py38h7b6447c_1
# pycparser                 2.20                       py_2
# pycurl                    7.43.0.6         py38h1ba5d50_0
# pydap                     3.2.2                    pypi_0    pypi
# pydocstyle                6.0.0              pyhd3eb1b0_0
# pyerfa                    1.7.3            py38h27cfd23_0
# pyflakes                  2.2.0              pyhd3eb1b0_0
# pygments                  2.8.1              pyhd3eb1b0_0
# pylint                    2.7.4            py38h06a4308_1
# pyls-black                0.4.6                hd3eb1b0_0
# pyls-spyder               0.3.2              pyhd3eb1b0_0
# pyodbc                    4.0.30           py38he6710b0_0
# pyodc                     1.0.3                    pypi_0    pypi
# pyopenssl                 20.0.1             pyhd3eb1b0_1
# pyparsing                 2.4.7              pyhd3eb1b0_0
# pyproj                    3.2.0                    pypi_0    pypi
# pyqt                      5.9.2            py38h05f1152_4
# pyrsistent                0.17.3           py38h7b6447c_0
# pyshp                     2.1.3                    pypi_0    pypi
# pysocks                   1.7.1            py38h06a4308_0
# pytables                  3.6.1            py38h9fd0a39_0
# pytest                    6.2.3            py38h06a4308_2
# python                    3.8.8                hdb3f193_5
# python-dateutil           2.8.1              pyhd3eb1b0_0
# python-jsonrpc-server     0.4.0                      py_0
# python-language-server    0.36.2             pyhd3eb1b0_0
# python-libarchive-c       2.9                pyhd3eb1b0_1
# pytz                      2021.1             pyhd3eb1b0_0
# pywavelets                1.1.1            py38h7b6447c_2
# pyxdg                     0.27               pyhd3eb1b0_0
# pyyaml                    5.4.1            py38h27cfd23_1
# pyzmq                     20.0.0           py38h2531618_1
# qdarkstyle                2.8.1                      py_0
# qt                        5.9.7                h5867ecd_1
# qtawesome                 1.0.2              pyhd3eb1b0_0
# qtconsole                 5.0.3              pyhd3eb1b0_0
# qtpy                      1.9.0                      py_0
# rasterio                  1.2.8                    pypi_0    pypi
# readline                  8.1                  h27cfd23_0
# regex                     2021.4.4         py38h27cfd23_0
# requests                  2.25.1             pyhd3eb1b0_0
# rioxarray                 0.7.0                    pypi_0    pypi
# ripgrep                   12.1.1                        0
# rope                      0.18.0                     py_0
# rtree                     0.9.7            py38h06a4308_1
# ruamel_yaml               0.15.100         py38h27cfd23_0
# scikit-image              0.18.1           py38ha9443f7_0
# scikit-learn              0.24.1           py38ha9443f7_0
# scipy                     1.6.2            py38had2a1c9_1
# seaborn                   0.11.1             pyhd3eb1b0_0
# secretstorage             3.3.1            py38h06a4308_0
# send2trash                1.5.0              pyhd3eb1b0_1
# setuptools                52.0.0           py38h06a4308_0
# shapely                   1.7.1                    pypi_0    pypi
# simplegeneric             0.8.1                    py38_2
# singledispatch            3.6.1           pyhd3eb1b0_1001
# sip                       4.19.13          py38he6710b0_0
# six                       1.15.0           py38h06a4308_0
# sniffio                   1.2.0            py38h06a4308_1
# snowballstemmer           2.1.0              pyhd3eb1b0_0
# snuggs                    1.4.7                    pypi_0    pypi
# sortedcollections         2.1.0              pyhd3eb1b0_0
# sortedcontainers          2.3.0              pyhd3eb1b0_0
# soupsieve                 2.2.1              pyhd3eb1b0_0
# sphinx                    4.0.1              pyhd3eb1b0_0
# sphinxcontrib             1.0                      py38_1
# sphinxcontrib-applehelp   1.0.2              pyhd3eb1b0_0
# sphinxcontrib-devhelp     1.0.2              pyhd3eb1b0_0
# sphinxcontrib-htmlhelp    1.0.3              pyhd3eb1b0_0
# sphinxcontrib-jsmath      1.0.1              pyhd3eb1b0_0
# sphinxcontrib-qthelp      1.0.3              pyhd3eb1b0_0
# sphinxcontrib-serializinghtml 1.1.4              pyhd3eb1b0_0
# sphinxcontrib-websupport  1.2.4                      py_0
# spyder                    4.2.5            py38h06a4308_0
# spyder-kernels            1.10.2           py38h06a4308_0
# sqlalchemy                1.4.15           py38h27cfd23_0
# sqlite                    3.35.4               hdfb4753_0
# statsmodels               0.12.2           py38h27cfd23_0
# sympy                     1.8              py38h06a4308_0
# tbb                       2020.3               hfd86e86_0
# tblib                     1.7.0                      py_0
# terminado                 0.9.4            py38h06a4308_0
# testpath                  0.4.4              pyhd3eb1b0_0
# textdistance              4.2.1              pyhd3eb1b0_0
# threadpoolctl             2.1.0              pyh5ca1d4c_0
# three-merge               0.1.1              pyhd3eb1b0_0
# tifffile                  2020.10.1        py38hdd07704_2
# tk                        8.6.10               hbc83047_0
# toml                      0.10.2             pyhd3eb1b0_0
# toolz                     0.11.1             pyhd3eb1b0_0
# tornado                   6.1              py38h27cfd23_0
# tqdm                      4.59.0             pyhd3eb1b0_1
# traitlets                 5.0.5              pyhd3eb1b0_0
# typed-ast                 1.4.2            py38h27cfd23_1
# typing_extensions         3.7.4.3            pyha847dfd_0
# ujson                     4.0.2            py38h2531618_0
# unicodecsv                0.14.1                   py38_0
# unixodbc                  2.3.9                h7b6447c_0
# urllib3                   1.26.4             pyhd3eb1b0_0
# watchdog                  1.0.2            py38h06a4308_1
# wcwidth                   0.2.5                      py_0
# webencodings              0.5.1                    py38_1
# webob                     1.8.7                    pypi_0    pypi
# werkzeug                  1.0.1              pyhd3eb1b0_0
# wheel                     0.36.2             pyhd3eb1b0_0
# widgetsnbextension        3.5.1                    py38_0
# wrapt                     1.12.1           py38h7b6447c_1
# wurlitzer                 2.1.0            py38h06a4308_0
# xarray                    0.19.0                   pypi_0    pypi
# xlrd                      2.0.1              pyhd3eb1b0_0
# xlsxwriter                1.3.8              pyhd3eb1b0_0
# xlwt                      1.3.0                    py38_0
# xmltodict                 0.12.0                     py_0
# xz                        5.2.5                h7b6447c_0
# yaml                      0.2.5                h7b6447c_0
# yapf                      0.31.0             pyhd3eb1b0_0
# zarr                      2.9.5                    pypi_0    pypi
# zeromq                    4.3.4                h2531618_0
# zict                      2.0.0              pyhd3eb1b0_0
# zipp                      3.4.1              pyhd3eb1b0_0
# zlib                      1.2.11               h7b6447c_3
# zope                      1.0                      py38_1
# zope.event                4.5.0                    py38_0
# zope.interface            5.3.0            py38h27cfd23_0
# zstd                      1.4.5                h9ceee32_0

# %%
# !conda update scikit-learn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: | ^C
# failed
#
# CondaError: KeyboardInterrupt

# %% [markdown]
# ## 3. Clean and combine the data <a name="clean"></a>
#
# Now lets clean up both datasets and join them together.

# %%
#Make everything a pandas df
df_x_orig = cds_xarray.to_dataframe()
df_y_orig = df_modis

#Create some copies that we will modify, leaving df_x_orig, df_y_orig unaltered in case we need to refer back
df_x = df_x_orig.copy()
df_y = df_y_orig.copy()

# %%
import numpy as np
#Reindex dfx to long1
df_x['latitude'] = np.round(df_x.index.get_level_values('latitude').values,3)
df_x['longitude'] = np.round((df_x.index.get_level_values('longitude').values +180) %360 - 180,3)
df_x['time'] = df_x.index.get_level_values('time').values
df_x = df_x.set_index(['latitude', 'longitude','time'], drop=True)


selected_x_columns = ['t2m','u10','v10'] #only use these columns, drop the others
df_x = df_x[selected_x_columns]




#Reindex dfy via a linear shift
#---ATTENTION---!> We add a linear shift of 0.0250 such that the coordinates match between the X and Y data
# We need to clarify the proper way to deal with this. Perhaps some interpolation method?
df_y['latitude'] = np.round(df_y.index.get_level_values('y').values,3) - 0.0250
df_y['longitude'] = np.round(df_y.index.get_level_values('x').values,3) - 0.0250

df_y = df_y.set_index(['latitude', 'longitude','time'], drop=True)

selected_y_columns = ['LST_Day_CMG'] #only use these columns, drop the others
df_y = df_y[selected_y_columns]

# %%
display(df_y)
display(df_x)

# %%
df_ML = df_y.merge(df_x, how = 'inner', left_index=True, right_index=True) #Merge
df_ML_clean = df_ML.dropna() #Get rid of nulls

# %%
df_x_orig

# %% [markdown]
# There is a curious effect whereby apparent artifacts are introduced in the plotting when dropping Nulls. Consider the `'LST_Day_CMG'` map for `df_ML` and then once we drop the nulls:

# %%
plotit(df_ML,'LST_Day_CMG')
plotit(df_ML_clean,'LST_Day_CMG')

# %% [markdown]
# There seems to be some artifact, evident in a small vertical line off the coast of South America. **Need to establish exactly what is causing this**. As far as I can tell it is a _plotting_ issue rather than an issue with the data processing itself, but need to confirm this.
#
# Going forward we will adopt `df_ML_clean` for our analysis.

# %%
display(df_ML_clean)

# %% [markdown]
# ## 4. Do some simple ML <a name="ML"></a>
#
# We now have all the data in a single df `df_ML_clean`
#
# Lets do some ML with this data.
#
# First it is actually useful to split up the df we just created (!) into two reduced x/y dfs:

# %%
x = df_ML_clean.drop(columns=['LST_Day_CMG']) #all the other columns. Don't use long3 - just for join
y = df_ML_clean[['LST_Day_CMG']] #just the 'y' column

display(x)
display(y)

# %% [markdown]
# Now lets create a training and test set:

# %%
from sklearn.model_selection import train_test_split

#Create train/test data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

#Create two dfs holding the test/train data
df_train = x_train.merge(y_train, how = 'inner', on=['latitude', 'longitude']) 
df_test = x_test.merge(y_test, how = 'inner', on=['latitude', 'longitude']) 

#Plot the train and test data
plotit(df_train,'LST_Day_CMG')
plotit(df_test,'LST_Day_CMG')

# %% [markdown]
# **Note again the vertical artifacts near the tip of S. America...**
#
#
# ...and now train using an RF

# %%
from sklearn.ensemble import RandomForestRegressor


#Make everything numpy arrays
x_train = x_train.to_numpy()
y_train = y_train.to_numpy().ravel() #flatten

x_test = x_test.to_numpy()
y_test = y_test.to_numpy().ravel()


# Initiate model 
rf = RandomForestRegressor(n_estimators = 10, verbose=1)

# Train the model on training data
rf.fit(x_train, y_train)

# %% [markdown]
# With a trained model we can then make some predictions, and then evaluate these predictions againsts the true (test) data

# %%
from sklearn.metrics import r2_score

y_pred = rf.predict(x_test)
training_score = rf.score(x_train, y_train)
testing_score = rf.score(x_test, y_test) # =r2_score(y_test, y_pred)
relative_error = (y_pred - y_test)/y_test

print ('Train/Test score:', training_score, testing_score)
print ('Max/min relative error:', max(abs(relative_error)), min(abs(relative_error)))

# %% [markdown]
# Not too bad! But then we did use the 2m surface temperature...
#
# We can also visualise how this error is spread geographically:

# %%
#Add the error and predictions to the test df i
df_test['relative_error'] = relative_error
df_test['y_pred'] = y_pred

#--Plot it up

#Actual
plotit(df_test,'LST_Day_CMG')

#Predicted
plotit(df_test,'y_pred')


#Error
plotit(df_test,'relative_error')
