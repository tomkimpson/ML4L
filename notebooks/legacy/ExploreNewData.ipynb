# %% [markdown]
# We have some new data from M+M, both at version 15 and version 20

# %%
v15 = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/climate.v015/climate.v015/639l_2/'
v20 = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/climate.v020/climate.v020/639l_2'

#clake  lsmoro  sfc

# %%
import xarray as xr

# %% [markdown]
# We can load `clake` and `lsmoro` with no problems, but `sfc` starts complaining:

# %%
for f in ['clake','lsmoro', 'sfc']:
    
    try:
        ds = xr.open_dataset(v15+f,
                             engine='cfgrib',
                             filter_by_keys={'typeOfLevel': 'surface'},
                             backend_kwargs={'indexpath': ''})
    except Exception as e:
        print('Errors for',f)
# Out:
# skipping variable: paramId==173 shortName='sr'
# Traceback (most recent call last):
#   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/cfgrib/dataset.py", line 660, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/cfgrib/dataset.py", line 593, in dict_merge
#     "key=%r value=%r new_value=%r" % (key, master[key], value)
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='time' value=Variable(dimensions=(), data=1385683200) new_value=Variable(dimensions=(), data=820454400)
# skipping variable: paramId==234 shortName='lsrh'
# Traceback (most recent call last):
#   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/cfgrib/dataset.py", line 660, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/cfgrib/dataset.py", line 593, in dict_merge
# ...

# %%
! grib_ls -p shortName /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/climate.v020/climate.v020/639l_2/sfc
# Out:
# /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/climate.v020/climate.v020/639l_2/sfc
# shortName
# anor
# isor
# slor
# sdor
# sr
# lsrh
# cvh
# cvl
# tvh
# tvl
# 10 of 10 messages in /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/climate.v020/climate.v020/639l_2/sfc
#
# 10 of 10 total messages in 1 files

# %%
sfc_names = ['anor', 'isor', 'slor', 'sdor', 'sr', 'lsrh', 'cvh', 'cvl', 'tvh','tvl']

# %%
ds_arr = []
for s in sfc_names:
    print(s)
    ds = xr.open_dataset(v15+'sfc',engine='cfgrib',filter_by_keys={'shortName': s},backend_kwargs={'indexpath': ''})
    ds_arr.append(ds)
# Out:
# anor
# isor
# slor
# sdor
# sr
# lsrh
# cvh
# cvl
# tvh
# tvl

# %%
for d in ds_arr:
    print (d.time)
# Out:
# <xarray.DataArray 'time' ()>
# array('2013-11-29T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time        datetime64[ns] 2013-11-29
#     step        timedelta64[ns] ...
#     surface     float64 ...
#     valid_time  datetime64[ns] ...
# Attributes:
#     long_name:      initial time of forecast
#     standard_name:  forecast_reference_time
# <xarray.DataArray 'time' ()>
# array('2013-11-29T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time        datetime64[ns] 2013-11-29
#     step        timedelta64[ns] ...
#     surface     float64 ...
#     valid_time  datetime64[ns] ...
# Attributes:
#     long_name:      initial time of forecast
#     standard_name:  forecast_reference_time
# <xarray.DataArray 'time' ()>
# array('2013-11-29T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time        datetime64[ns] 2013-11-29
#     step        timedelta64[ns] ...
#     surface     float64 ...
#     valid_time  datetime64[ns] ...
# ...

# %%
xr.merge(ds_arr,compat='override')
# Out:
# <xarray.Dataset>
# Dimensions:     (values: 542080)
# Coordinates:
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     surface     float64 ...
#     latitude    (values) float64 ...
#     longitude   (values) float64 ...
#     valid_time  datetime64[ns] ...
# Dimensions without coordinates: values
# Data variables:
#     anor        (values) float32 ...
#     isor        (values) float32 ...
#     slor        (values) float32 ...
#     sdor        (values) float32 ...
#     sr          (values) float32 ...
#     lsrh        (values) float32 ...
#     cvh         (values) float32 ...
#     cvl         (values) float32 ...
#     tvh         (values) float32 ...
#     tvl         (values) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
# ...

# %% [markdown]
# ---
#
#
#
# 1. Which features are constant?
#
# 2. Split grib data into monthly variable features and constant features. v15 constants, v20 constants
#
#
#
#
# ERA_sfc: sp, msl, 10u, 10v, 2t
# ERA_skin:
# ERA_skt
#
#
#
#
#         aluvp, aluvd, alnip, alnid, cl, cvl, mvh, istl1, istl2, slt, sdfor, z, sd, store, isor, anor, spor, 2d, lsm, fal
#
#     2. `sfc_unstructured_...` 3 years of data (2018,209,2020), hourly grain

# %%
! grib_ls /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/ERA_sfc/sfc_unstructured_2018_01.grib | head -20
# Out:
# /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/ERA_sfc/sfc_unstructured_2018_01.grib
# edition      centre       typeOfLevel  level        dataDate     stepRange    dataType     shortName    packingType  gridType
# 1            ecmf         surface      0            20180101     0            an           sp           grid_simple  reduced_gg
# 1            ecmf         surface      0            20180101     0            an           msl          grid_simple  reduced_gg
# 1            ecmf         surface      0            20180101     0            an           10u          grid_simple  reduced_gg
# 1            ecmf         surface      0            20180101     0            an           10v          grid_simple  reduced_gg
# 1            ecmf         surface      0            20180101     0            an           2t           grid_simple  reduced_gg
# ...

# %%
f = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/ERA_skin/sfc_skin_unstructured_2010_01.grib'
ds = xr.open_dataset(f,engine='cfgrib',filter_by_keys={'typeOfLevel': 'surface'})

# %%
f = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/ERA_skin/sfc_skin_unstructured_2018_01.grib'
ds_istl = xr.open_dataset(f,engine='cfgrib',filter_by_keys={'shortName': 'istl1'})
ds_lsm = xr.open_dataset(f,engine='cfgrib',filter_by_keys={'shortName': 'lsm'})
# Out:
# Ignoring index file '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/ERA_skin/sfc_skin_unstructured_2018_01.grib.02ccc.idx' incompatible with GRIB file

# %%
ds_istl
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 744, values: 542080)
# Coordinates:
#     number               int64 ...
#   * time                 (time) datetime64[ns] 2018-01-01 ... 2018-01-31T23:0...
#     step                 timedelta64[ns] ...
#     depthBelowLandLayer  float64 ...
#     latitude             (values) float64 ...
#     longitude            (values) float64 ...
#     valid_time           (time) datetime64[ns] ...
# Dimensions without coordinates: values
# Data variables:
#     istl1                (time, values) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2022-04-09T11:45 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
ds_lsm
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 744, values: 542080)
# Coordinates:
#     number      int64 ...
#   * time        (time) datetime64[ns] 2018-01-01 ... 2018-01-31T23:00:00
#     step        timedelta64[ns] ...
#     surface     float64 ...
#     latitude    (values) float64 ...
#     longitude   (values) float64 ...
#     valid_time  (time) datetime64[ns] ...
# Dimensions without coordinates: values
# Data variables:
#     lsm         (time, values) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2022-04-09T11:46 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
ds= xr.merge([ds_istl,ds_lsm])

# %%
dsf = ds.to_dataframe()

# %%
dsf.query('lsm > 0.5')
# Out:
#                             number   step  depthBelowLandLayer   latitude  \
# time                values
# 2018-01-01 00:00:00 2113         0 0 days                  0.0  83.325378
#                     2114         0 0 days                  0.0  83.325378
#                     2115         0 0 days                  0.0  83.325378
#                     2116         0 0 days                  0.0  83.325378
#                     2117         0 0 days                  0.0  83.325378
# ...                            ...    ...                  ...        ...
# 2018-01-31 23:00:00 542075       0 0 days                  0.0 -89.784877
#                     542076       0 0 days                  0.0 -89.784877
#                     542077       0 0 days                  0.0 -89.784877
#                     542078       0 0 days                  0.0 -89.784877
#                     542079       0 0 days                  0.0 -89.784877
#
# ...

# %%
ds2 = xr.open_dataset(f,engine='cfgrib',filter_by_keys={'typeOfLevel': 'depthBelowLandLayer'})
# Out:
# Ignoring index file '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/ERA_skin/sfc_skin_unstructured_2010_01.grib.923a8.idx' incompatible with GRIB file
# skipping variable: paramId==36 shortName='istl2'
# Traceback (most recent call last):
#   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/cfgrib/dataset.py", line 660, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/cfgrib/dataset.py", line 593, in dict_merge
#     "key=%r value=%r new_value=%r" % (key, master[key], value)
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=7.0)
