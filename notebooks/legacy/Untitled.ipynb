# %%
path = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ML_1648640211/'

# %%
import pandas as pd
df = pd.read_pickle(path+'predictions.pkl')

#Create some new columns for the errors
df['error_ERA'] = df.MODIS_LST - df.skt
df['error_ERA_abs'] = abs(df.MODIS_LST - df.skt)

df['error_NN'] = df.MODIS_LST - df.predictions
df['error_NN_abs'] = abs(df.MODIS_LST - df.predictions)

#Surface some useful numbers
print('Absolute error:')
print('--------------------------------')
print("NN model: Mean error, Median error, Std deviation:",df.error_NN_abs.mean(), df.error_NN_abs.median(),df.error_NN_abs.std())
print("ERA5: Mean error, Median error, Std deviation    :", df.error_ERA_abs.mean(), df.error_ERA_abs.median(),df.error_ERA_abs.std())

print('Biased error:')
print('--------------------------------')
print("NN model: Mean bias, Median bia, Std deviation:",df.error_NN.mean(), df.error_NN.median(),df.error_NN.std())
print("ERA5: Mean bias, Median bias, Std deviation::    ", df.error_ERA.mean(), df.error_ERA.median(),df.error_ERA.std())
# Out:
# Absolute error:
# --------------------------------
# NN model: Mean error, Median error, Std deviation: 3.0727212 2.351532 2.7390487
# ERA5: Mean error, Median error, Std deviation    : 3.7469294 2.9239807 3.3043458
# Biased error:
# --------------------------------
# NN model: Mean bias, Median bia, Std deviation: 0.20287068 0.35064697 4.1113067
# ERA5: Mean bias, Median bias, Std deviation::     -0.71137625 -0.6607971 4.944907

# %%
ML_file = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/ML_data_ERA_MODIS_joined.pkl'
df_og = pd.read_pickle(ML_file)

# %%
df

# %%
df_og
# Out:
#            index  latitude_ERA  longitude_ERA    index_MODIS  latitude_MODIS  \
# 0              0     19.531610     -154.96875    1502.533333       19.505556
# 1              1     19.812640     -155.25000    3216.000000       20.000000
# 2              2     54.660397     -164.53125    6173.020000       54.639667
# 3              3     54.660397     -164.06250    7701.694444       54.751852
# 4              4     54.660397     -163.59375    7877.250000       54.763889
# ...          ...           ...            ...            ...             ...
# 105640205   5425     70.117048       69.75000  817942.000000       69.983333
# 105640206   5426     70.117048       71.25000  817987.000000       69.983333
# 105640207   5427     70.117048       72.00000  818011.217391       69.983333
# 105640208   5428     70.117048       74.25000  818075.000000       69.983333
# 105640209   5429     70.117048       75.00000  818094.000000       69.983333
#
#            longitude_MODIS  band  spatial_ref   MODIS_LST  index_ERA  ...  \
# 0              -154.898889   1.0          0.0  296.375031     7884.0  ...
# 1              -155.283333   1.0          0.0  292.494568     7822.0  ...
# 2              -164.566000   1.0          0.0  270.973816     1676.0  ...
# 3              -164.093519   1.0          0.0  264.770844     1677.0  ...
# 4              -163.658333   1.0          0.0  261.147736     1678.0  ...
# ...                    ...   ...          ...         ...        ...  ...
# 105640205        69.750000   1.0          0.0  241.867874       77.0  ...
# 105640206        71.250000   1.0          0.0  243.849625       79.0  ...
# 105640207        72.057246   1.0          0.0  243.605469       80.0  ...
# 105640208        74.183333   1.0          0.0  240.991898       83.0  ...
# 105640209        74.816667   1.0          0.0  240.527832       84.0  ...
#
#                anor      slor         d2m       lsm       fal         skt  \
# 0         -1.345057  0.020737  290.720581  0.859402  0.098755  298.796295
# 1         -1.119782  0.060927  287.956909  0.994300  0.118576  297.434967
# 2          0.525316  0.044459  271.542847  0.857640  0.628402  272.448639
# 3          1.198739  0.045005  270.318237  0.673016  0.794266  269.415436
# 4         -1.159774  0.040498  272.171753  0.550489  0.733368  272.880280
# ...             ...       ...         ...       ...       ...         ...
# 105640205  0.227795  0.002641  238.491577  0.990330  0.761208  240.706482
# 105640206 -0.167822  0.000880  239.665405  0.857928  0.752846  241.774841
# 105640207  0.243158  0.000470  241.042358  0.906867  0.759819  242.374451
# 105640208 -0.196603  0.002612  235.782593  0.993482  0.752739  238.112732
# 105640209  0.483895  0.002612  235.917358  0.989185  0.752800  237.513123
#
#            L2_distance  MODIS_idx  H_distance                time
# 0             0.008203     1055.0    9.251614 2018-01-02 00:00:00
# 1             0.036621     1051.0   21.240943 2018-01-02 00:00:00
# 2             0.039785     1039.0   15.327788 2018-01-02 00:00:00
# 3             0.029026     1040.0   13.643631 2018-01-02 00:00:00
# 4             0.065755     1041.0   18.430069 2018-01-02 00:00:00
# ...                ...        ...         ...                 ...
# 105640205     0.066873       29.0   16.976636 2020-12-30 09:00:00
# 105640206     0.066916       30.0   16.976636 2020-12-30 09:00:00
# 105640207     0.090778       31.0   17.866478 2020-12-30 09:00:00
# 105640208     0.089844       32.0   17.818390 2020-12-30 09:00:00
# 105640209     0.062589       33.0   16.812966 2020-12-30 09:00:00
#
# [105640210 rows x 41 columns]

# %%
df_og['err'] = df['error_ERA']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/bin/conda/envs/GPU/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/bin/conda/envs/GPU/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/bin/conda/envs/GPU/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'error_ERA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_55543/3376862833.py in <module>
# ----> 1 df_og['err'] = df['error_ERA']
#
# ~/bin/conda/envs/GPU/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/bin/conda/envs/GPU/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'error_ERA'

# %%
all_features = [ 'sp', 'msl', 'u10', 'v10','t2m',
                         'aluvp', 'aluvd', 'alnip', 'alnid', 'cl',
                         'cvl', 'cvh', 'slt', 'sdfor', 'z', 'sd', 'sdor', 'isor', 'anor', 'slor',
                         'd2m', 'lsm', 'fal','skt']

# %%
removed_feature = 'sp'
b = [n for n in all_features if n != removed_feature]

# %%
b
# Out:
# ['u10',
#  'v10',
#  't2m',
#  'aluvp',
#  'aluvd',
#  'alnip',
#  'alnid',
#  'cl',
#  'cvl',
#  'cvh',
#  'slt',
#  'sdfor',
#  'z',
#  'sd',
#  'sdor',
#  'isor',
#  'anor',
#  'slor',
#  'd2m',
#  'lsm',
#  'fal',
#  'skt']

# %%
zz
# Out:
# 'msl'

# %%
import shutil

# %%
import pandas as pd 
input_file = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/ML_data_ERA_MODIS_joined.pkl'
df = pd.read_pickle(input_file)

# %%
train_condition = pd.to_datetime("2019-01-01 00:00:00")
test_condition  = pd.to_datetime("2020-01-01 00:00:00")
idx_train = df.time < train_condition 
idx_valid = (train_condition <= df.time) & (df.time < test_condition)

# %%
sum(idx_valid)
# Out:
# 35645741

# %%
 #Separate into train/valid/test based on time
    idx_train = df.time < train_condition 
    idx_valid = train_condition <= df.time < test_condition 
    idx_test  = df.time > test_condition 

    x_train = features_normed[idx_train] 
    y_train = target_normed[idx_train]
    
    x_valid = features_normed[idx_valid] 
    y_vallid = target_normed[idx_valid]
