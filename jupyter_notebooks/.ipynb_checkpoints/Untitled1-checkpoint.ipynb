# %%
import tensorflow as tf
model = tf.keras.models.load_model('model_epochs100_batch128')
# Out:
# 2022-03-08 13:45:00.902367: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-08 13:45:01.456934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 358 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:21:00.0, compute capability: 8.0

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 23)               47
#  n)
#
#  layer1 (Dense)              (None, 11)                264
#
#  layer2 (Dense)              (None, 11)                132
#
#  output (Dense)              (None, 1)                 12
#
# =================================================================
# Total params: 455
# Trainable params: 408
# Non-trainable params: 47
# _________________________________________________________________

# %%
import glob
root = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/ML4L/ECMWF_files/raw/'
all_files = sorted(glob.glob(root+'outputs_multi/*.pkl'))

import pandas as pd
df = pd.read_pickle(root+'ML_data.pkl')


df_filtered = df.query('distance <= 1.0')


training_data = df_filtered.query('time < "2019-01-01 00:00:00"')
test_data = df_filtered.query('time >= "2020-01-01 00:00:00"')


features = ['sp', 'msl', 'u10', 'v10','t2m',
            'aluvp', 'aluvd', 'alnip', 'alnid', 'cl',
            'cvl', 'cvh', 'slt', 'sdfor', 'z', 'sd', 'sdor', 'isor', 'anor', 'slor',
            'd2m', 'lsm', 'fal'] 
targets = ['MODIS_LST']

x_train = training_data[features]
y_train = training_data[targets]

x_test = test_data[features]
y_test = test_data[targets]

# %%
#Select 24 hours of test data
test_data_24 = test_data.query(' "2020-01-06 00:00:00" <= time < "2020-01-07 00:00:00"')

# %%
#Make some predictions, just for that 24 hours
predictions = model.predict(test_data_24[features])
# Out:
# 2022-03-08 13:45:55.573080: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2022-03-08 13:45:55.573255: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at matmul_op_impl.h:438 : INTERNAL: Attempting to perform BLAS operation using StreamExecutor without BLAS support
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipykernel_12621/3004463052.py in <module>
#       1 #Make some predictions, just for that 24 hours
# ----> 2 predictions = model.predict(test_data_24[features])
#
# ~/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/bin/conda/envs/GPU/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# InternalError:  Attempting to perform BLAS operation using StreamExecutor without BLAS support
# 	 [[node sequential/layer1/MatMul
#  (defined at /home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/layers/core/dense.py:199)
# ]] [Op:__inference_predict_function_1037]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node sequential/layer1/MatMul:
# In[0] sequential/normalization/truediv (defined at /home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/layers/preprocessing/normalization.py:258)
# In[1] sequential/layer1/MatMul/ReadVariableOp:
#
# Operation defined at: (most recent call last)
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/runpy.py", line 193, in _run_module_as_main
# >>>     "__main__", mod_spec)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/runpy.py", line 85, in _run_code
# >>>     exec(code, run_globals)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
# >>>     app.launch_new_instance()
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/traitlets/config/application.py", line 846, in launch_instance
# >>>     app.start()
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 677, in start
# >>>     self.io_loop.start()
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
# >>>     self.asyncio_loop.run_forever()
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
# >>>     self._run_once()
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
# >>>     handle._run()
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/asyncio/events.py", line 88, in _run
# >>>     self._context.run(self._callback, *self._args)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_queue
# >>>     await self.process_one()
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 460, in process_one
# >>>     await dispatch(*args)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 367, in dispatch_shell
# >>>     await result
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 662, in execute_request
# >>>     reply_content = await reply_content
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 360, in do_execute
# >>>     res = shell.run_cell(code, store_history=store_history, silent=silent)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
# >>>     return super().run_cell(*args, **kwargs)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2958, in run_cell
# >>>     raw_cell, store_history, silent, shell_futures)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3003, in _run_cell
# >>>     return runner(coro)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
# >>>     coro.send(None)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3229, in run_cell_async
# >>>     interactivity=interactivity, compiler=compiler, result=result)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_ast_nodes
# >>>     if (await self.run_code(code, result,  async_=asy)):
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3524, in run_code
# >>>     exec(code_obj, self.user_global_ns, self.user_ns)
# >>>
# >>>   File "/tmp/ipykernel_12621/3004463052.py", line 2, in <module>
# >>>     predictions = model.predict(test_data_24[features])
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/engine/training.py", line 1789, in predict
# >>>     tmp_batch_outputs = self.predict_function(iterator)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/engine/training.py", line 1621, in predict_function
# >>>     return step_function(self, iterator)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/engine/training.py", line 1611, in step_function
# >>>     outputs = model.distribute_strategy.run(run_step, args=(data,))
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/engine/training.py", line 1604, in run_step
# >>>     outputs = model.predict_step(data)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/engine/training.py", line 1572, in predict_step
# >>>     return self(x, training=False)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/engine/base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/engine/sequential.py", line 373, in call
# >>>     return super(Sequential, self).call(inputs, training=training, mask=mask)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/engine/functional.py", line 452, in call
# >>>     inputs, training=training, mask=mask)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/engine/functional.py", line 589, in _run_internal_graph
# >>>     outputs = node.layer(*args, **kwargs)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/engine/base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/k/kimpson/bin/conda/envs/GPU/lib/python3.7/site-packages/keras/layers/core/dense.py", line 199, in call
# >>>     outputs = tf.matmul(a=inputs, b=self.kernel)
# >>>

# %%
import geopandas as gpd
def plot_map(df,x,y,q): #slow plotting function
        
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df[x], df[y]))
    
    #Plot the world
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
    ax=world.boundary.plot(figsize=(24,12))
    
    gdf.plot(ax=ax,column=q,cmap='plasma',markersize=1,legend=True)

# %%
plot_map(test_data_24,'longitude_ERA', 'latitude_ERA', 'MODIS_LST')

# %%
test_data_24.plot.scatter('longitude_ERA','latitude_ERA')
# Out:
# <AxesSubplot:xlabel='longitude_ERA', ylabel='latitude_ERA'>

# %%
t = test_data_24.droplevel(0).reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3382/4052770596.py in <module>
# ----> 1 t = test_data_24.droplevel(0).reset_index()
#
# ~/bin/conda/envs/GPU/lib/python3.7/site-packages/pandas/core/generic.py in droplevel(self, level, axis)
#     864         """
#     865         labels = self._get_axis(axis)
# --> 866         new_labels = labels.droplevel(level)
#     867         return self.set_axis(new_labels, axis=axis, inplace=False)
#     868
#
# ~/bin/conda/envs/GPU/lib/python3.7/site-packages/pandas/core/indexes/base.py in droplevel(self, level)
#    1860         levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
#    1861
# -> 1862         return self._drop_level_numbers(levnums)
#    1863
#    1864     @final
#
# ~/bin/conda/envs/GPU/lib/python3.7/site-packages/pandas/core/indexes/base.py in _drop_level_numbers(self, levnums)
#    1872         if len(levnums) >= self.nlevels:
#    1873             raise ValueError(
# -> 1874                 f"Cannot remove {len(levnums)} levels from an index with "
#    1875                 f"{self.nlevels} levels: at least one level must be left."
#    1876             )
#
# ValueError: Cannot remove 1 levels from an index with 1 levels: at least one level must be left.

# %%
test_data_24
# Out:
#           level_0  index  index_ERA  values             sp        msl  \
# 48366892       18     65         65      65  102437.484375  102576.50
# 48366893       19     66         66      66  101819.484375  102582.00
# 48366894       20     67         67      67  101063.484375  102598.75
# 48366895       21     68         68      68  100583.484375  102636.00
# 48366896       22     69         69      69  100725.484375  102668.50
# ...           ...    ...        ...     ...            ...        ...
# 48427437     1635  22564      22564   22564   81447.671875   99992.25
# 48427438     1636  22565      22565   22565   84134.671875   99967.25
# 48427439     1637  22566      22566   22566   86004.671875   99932.00
# 48427440     1638  22567      22567   22567   88499.671875   99897.25
# 48427441     1639  22568      22568   22568   93367.671875   99849.75
#
#                u10       v10         t2m  latitude_ERA  ...       lsm  \
# 48366892 -5.920868 -2.249619  238.843552     69.554988  ...  0.919435
# 48366893 -5.890594 -0.789658  239.136520     69.554988  ...  0.955846
# 48366894 -5.489227  0.655655  238.833786     69.554988  ...  0.996936
# 48366895 -4.108368  1.628311  235.542770     69.554988  ...  0.999228
# 48366896 -2.699188  2.267960  232.882614     69.554988  ...  1.000000
# ...            ...       ...         ...           ...  ...       ...
# 48427437 -0.092361  8.252518  260.870972    -69.554988  ...  1.000000
# 48427438  0.867599  7.528885  262.271362    -69.554988  ...  1.000000
# 48427439  1.563889  5.760330  263.324097    -69.554988  ...  1.000000
# 48427440  1.793381  4.171463  264.806519    -69.554988  ...  1.000000
# 48427441  1.794357  3.193924  267.652222    -69.554988  ...  1.000000
#
#                fal index_MODIS latitude_MODIS  longitude_MODIS band  \
# 48366892  0.663129      247117          69.55      -162.750000    1
# 48366893  0.680707      247139          69.55      -162.016667    1
# 48366894  0.697812      247162          69.55      -161.250000    1
# 48366895  0.720365      247184          69.55      -160.516667    1
# 48366896  0.728956      247207          69.55      -159.750000    1
# ...            ...         ...            ...              ...  ...
# 48427437  0.850004        6007         -69.55        65.250000    1
# 48427438  0.850004        6029         -69.55        65.983333    1
# 48427439  0.850004        6052         -69.55        66.750000    1
# 48427440  0.850004        6074         -69.55        67.483333    1
# 48427441  0.850004        6097         -69.55        68.250000    1
#
#           spatial_ref   MODIS_LST  distance  MODIS_idx
# 48366892            0  238.599655  0.554674     247117
# 48366893            0  237.633743  0.852543     247139
# 48366894            0  239.007065  0.554674     247162
# 48366895            0  235.139999  0.852543     247184
# 48366896            0  231.563751  0.554674     247207
# ...               ...         ...       ...        ...
# 48427437            0  264.316254  0.554674       6007
# 48427438            0  265.380005  0.852543       6029
# 48427439            0  266.256256  0.554674       6052
# 48427440            0  268.473755  0.852543       6074
# 48427441            0  269.686249  0.554674       6097
#
# [13564 rows x 42 columns]

# %%
test_data_24.plot.scatter('level_0','MODIS_LST')
# Out:
# <AxesSubplot:xlabel='level_0', ylabel='MODIS_LST'>
